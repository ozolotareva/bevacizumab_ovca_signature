# %%
import sys,os
import numpy as np
import pandas as pd
import random
import math
from time import time
from datetime import datetime

import matplotlib.pyplot as plt
import seaborn as sns


sys.path.append('unpast/') # path to UnPaSt
from unpast.run_unpast import unpast

from unpast.utils.method import prepare_input_matrix, zscore
from unpast.utils.io import read_bic_table, write_bic_table 

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# functions to rename genes 
gene_info = pd.read_csv("../data/gene_id_mapping.tsv", sep ="\t",index_col=0)
gene_info.set_index("ensembl_gene_id",inplace=True)
ens2hgnc = gene_info["hgnc_symbol"].dropna().to_dict() 
def rename_gene(g,mapper=ens2hgnc, not_mapped = "", keep_not_mapped = False):
    if g in ens2hgnc.keys():
        return mapper[g]
    else:
        if keep_not_mapped:
            return g
        else:
            return not_mapped
def rename_genes_in_biclusters(biclusters, rename_gene_func = rename_gene):
    renamed_biclusters = biclusters.copy()
    renamed_biclusters["genes"] = renamed_biclusters["genes"].apply(lambda genes: set([rename_gene_func(x, keep_not_mapped=True) for x in genes]))
    renamed_biclusters["genes_up"] = renamed_biclusters["genes_up"].apply(lambda genes: set([rename_gene_func(x, keep_not_mapped=True) for x in genes]))
    renamed_biclusters["genes_down"] = renamed_biclusters["genes_down"].apply(lambda genes: set([rename_gene_func(x, keep_not_mapped=True) for x in genes]))
    return renamed_biclusters

def rename_genes_in_exprs(data, rename_gene_func = rename_gene):
    renamed_data = data.copy()
    renamed_data.index = [rename_gene_func(x, keep_not_mapped=True) for x in renamed_data.index ]
    # drop duplicates 
    renamed_data = renamed_data[~renamed_data.index.duplicated()]
    return renamed_data

# %% [markdown]
# # analysis of biclusters prioritized by RSF

# %%
exprs_file = "../data/UKE_244.exprs.tsv.gz" 
annot = pd.read_csv("../data/UKE.sample_annotation_v4_181samples.tsv",sep ="\t",index_col=0)

out_dir = "unpast_results/" 
basename = 'UKE_244'
analysis_seed =  42 
sele_bics_ids = [84,130,70,90,109,41,95] 

exprs = pd.read_csv(exprs_file,sep="\t",index_col=0)
print(exprs.shape)
outfile = out_dir+basename+".consensus_seed="+str(analysis_seed)+".n_runs=10.biclusters.tsv"
exprs_z = prepare_input_matrix(exprs, min_n_samples=5,ceiling=3)
exprs_z_rn = exprs_z.copy()
exprs_z_rn.index = [rename_gene(x, keep_not_mapped=True) for x in exprs_z.index]
uke_bics = read_bic_table(outfile)
uke_bics["genes"] = uke_bics["genes"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
uke_bics["genes_up"] = uke_bics["genes_up"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
uke_bics["genes_down"] = uke_bics["genes_down"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
uke_bics["n_genes"] = uke_bics["genes"].apply(lambda x: len(x))
uke_bics.head()
# Out:
# (23758, 244)
#          SNR  n_genes  n_samples  \
# id
# 0   3.348530        2        111
# 1   2.673952        2         75
# 2   2.454886        2         57
# 3   2.268912        2         97
# 4   2.184297        4         14
#
#                                                 genes  \
# id
# 0                        {ENSG00000236209, LINC01291}
# 1                                       {GATD3, PWP2}
# 2                              {RHD, ENSG00000261349}
# 3                                        {ZIC4, ZIC1}
# 4   {ENSG00000285822, ENSG00000231421, TUFMP1, LIN...
#
#                                               samples  \
# id
# 0   {T0928, T4979, T6620, T7003, T6788, T6068, T66...
# 1   {T6587, T2522, T6621, T0928, T4175, T4979, T69...
# 2   {T6621, T2522, T1189, T0799, T6911, T6991, T63...
# 3   {T6943, T6620, T5991, T6788, T1702, T6068, T66...
# 4   {T2434, T3473, T6789, T6936, T6795, T0430, T67...
#
#                                              genes_up  \
# id
# 0                                                  {}
# 1                                       {GATD3, PWP2}
# 2                                                  {}
# 3                                        {ZIC4, ZIC1}
# 4   {ENSG00000285822, ENSG00000231421, TUFMP1, LIN...
#
#                       genes_down               gene_indexes  \
# id
# 0   {ENSG00000236209, LINC01291}             {19402, 22351}
# 1                             {}              {22705, 3483}
# 2         {RHD, ENSG00000261349}              {9330, 21459}
# 3                             {}              {22442, 8551}
# 4                             {}  {1698, 19121, 17842, 469}
#
#                                        sample_indexes direction  \
# id
# 0   {1, 2, 5, 7, 9, 10, 14, 21, 22, 23, 24, 25, 29...      DOWN
# 1   {130, 131, 133, 134, 139, 14, 142, 144, 17, 16...        UP
# 2   {128, 1, 2, 3, 133, 134, 135, 8, 136, 11, 12, ...      DOWN
# 3   {3, 6, 10, 28, 37, 39, 40, 41, 42, 43, 44, 45,...        UP
# 4   {161, 2, 131, 98, 130, 8, 44, 109, 176, 213, 1...        UP
#
#     detected_n_times                                                ids
# id
# 0                 10  seed=107473_0 seed=116739_1 seed=146316_0 seed...
# 1                 10  seed=107473_3 seed=116739_5 seed=146316_4 seed...
# 2                  7  seed=146316_6 seed=256787_3 seed=26225_72 seed...
# 3                 10  seed=107473_7 seed=116739_99 seed=146316_9 see...
# 4                 10  seed=107473_2 seed=116739_4 seed=146316_11 see...

# %%
from aux import make_similar_biclusters

exprs_dasl = pd.read_csv("../data/DASL_377.exprs.tsv.gz",sep="\t",index_col=0)
exprs_dasl_z = prepare_input_matrix(exprs_dasl, min_n_samples=5,ceiling=3)
exprs_z_dasl = zscore(exprs_dasl.copy())
exprs_z_rn_dasl = rename_genes_in_exprs(exprs_z_dasl.copy())
annot_dasl = pd.read_csv("../data/DASL.annotation_Kommoss.tsv.gz",sep ="\t",index_col=0)
print(exprs_dasl.shape)
dasl_bics, gene_sets_stat = make_similar_biclusters(uke_bics.loc[sele_bics_ids, :],
                                                    exprs_z_rn_dasl,
                                                    seed=analysis_seed)

#dasl_bics = dasl_bics.loc[dasl_bics["SNR"]>1.5,:]
dasl_bics = dasl_bics.loc[dasl_bics["n_genes"]>1,:]
dasl_bics
# Out:
# (19369, 377)
#                                         sample_indexes n_samples  \
# 84   {5, 6, 8, 9, 11, 14, 16, 17, 19, 20, 21, 23, 2...       182
# 130  {3, 259, 5, 6, 133, 136, 260, 10, 138, 266, 16...        53
# 70   {1, 2, 3, 5, 6, 7, 10, 12, 14, 16, 18, 19, 22,...       139
# 90   {1, 2, 3, 7, 9, 10, 11, 15, 16, 17, 21, 25, 26...       181
# 109  {4, 5, 9, 26, 29, 34, 35, 37, 46, 47, 48, 49, ...        81
# 41   {4, 11, 18, 22, 34, 37, 45, 59, 70, 75, 78, 88...        91
# 95   {2, 3, 5, 7, 8, 11, 16, 18, 19, 22, 24, 27, 28...       170
#
#                                                  genes n_genes direction  \
# 84                                    {PTH2R, SLCO6A1}       2      DOWN
# 130               {ADIPOQ, CIDEC, CIDEA, FABP4, RERGL}       5        UP
# 70   {NTM, ADAM12, ALPK2, LRRC15, PRRX1, TENM3, C5o...      19        UP
# 90                                      {NR4A1, NR4A3}       2        UP
# 109                      {MAGEA10, LINC00898, MAGEA9B}       3        UP
# 41                                        {ZIC2, ZIC5}       2        UP
# 95                                      {HOXB9, HOXB8}       2        UP
#
#                                                samples  \
# 84   {X5800701030_A, X5801106019_H, X5800701021_K, ...
# 130  {X5801106023_I, X5800710008_C, X5800710041_H, ...
# 70   {X5801106023_I, X5800710041_H, X5800710009_G, ...
# 90   {X5800710009_G, X5800710007_J, X5800744007_F, ...
# 109  {X5800744041_G, X5800701055_B, X5800710007_J, ...
# 41   {X5801106019_H, X5800710007_J, X5800710052_L, ...
# 95   {X5800710041_H, X5800710009_G, X5800701055_B, ...
#
#                                           gene_indexes  \
# 84                                       {16570, 8165}
# 130                 {13921, 13186, 12104, 3722, 15038}
# 70   {7172, 8716, 8336, 2065, 531, 13588, 792, 7996...
# 90                                        {4699, 5141}
# 109                               {16600, 18402, 5260}
# 41                                         {7519, 575}
# 95                                       {12187, 4790}
#
#                                               genes_up        genes_down  \
# 84                                                  {}  {PTH2R, SLCO6A1}
# 130               {ADIPOQ, CIDEC, CIDEA, FABP4, RERGL}                {}
# 70   {NTM, ADAM12, ALPK2, LRRC15, PRRX1, TENM3, C5o...                {}
# 90                                      {NR4A1, NR4A3}                {}
# 109                      {MAGEA10, LINC00898, MAGEA9B}                {}
# 41                                        {ZIC2, ZIC5}                {}
# 95                                      {HOXB9, HOXB8}                {}
#
#           SNR
# 84   1.583804
# 130  1.542764
# 70   1.528053
# 90   1.526702
# 109  1.364288
# 41   1.581742
# 95   1.616848

# %%
for i in sele_bics_ids:
    print("b%s"%i,"\t"," ".join(sorted(uke_bics.loc[i,"genes"])),"\t",
          " ".join(sorted(dasl_bics.loc[i,"genes"])))
# Out:
# b84 	 ENSG00000249721 LINC00491 LINC01456 PTH2R SLCO6A1 	 PTH2R SLCO6A1
# b130 	 ADIPOQ CADM3-AS1 CIDEA CIDEC CYP4F24P FABP4 IGLON5 LINC01096 MIR646HG NKX2-5 RERGL TRARG1 	 ADIPOQ CIDEA CIDEC FABP4 RERGL
# b70 	 ADAM12 ADAMTS12 ALPK2 C1QTNF6 C5orf46 CALB2 CASC18 CCL11 CHRNA1 CHSY3 COL11A1 CORIN CSMD2 CTSK DPP10 EDIL3 ENSG00000222022 ENSG00000222032 ENSG00000232821 ENSG00000236841 ENSG00000254605 ENSG00000256654 ENSG00000265579 EPYC GALNT5 GREM1 INHBA-AS1 ISL2 KCNA1 KIF26B-AS1 LINC00922 LINC00968 LINC01429 LINC01561 LINC01614 LINC01638 LINC01929 LINC02544 LNCAROD LRRC15 MEGF10 MMP11 MMP13 NETO1 NTM NTMT2 OMD PLAU PRRX1 RFX8 RPL29P19 RTL3 SERPINB7 SRPX2 TENM3 TMEM158 VCAN XIRP1 	 ADAM12 ALPK2 C5orf46 CCL11 COL11A1 CSMD2 CTSK GREM1 LRRC15 MEGF10 MMP11 MMP13 NETO1 NTM PLAU PRRX1 TENM3 TMEM158 VCAN
# b90 	 ENSG00000261026 ENSG00000285848 NR4A1 NR4A3 PRR9 TEX26-AS1 	 NR4A1 NR4A3
# b109 	 ENSG00000279712 EPIC1 KASH5 LINC00898 LINC01854 LINC01992 MAGEA10 MAGEA9B OR56A3 	 LINC00898 MAGEA10 MAGEA9B
# b41 	 FOXD1 PAX6 ZIC2 ZIC3 ZIC5 	 ZIC2 ZIC5
# b95 	 ENSG00000272763 GATA2-AS1 HOXB-AS4 HOXB8 HOXB9 	 HOXB8 HOXB9

# %% [markdown]
# ### ORA

# %%
# only genes presenting in both UKE and DASL are accounted
import gseapy
names = gseapy.get_library_name()

#annot = pd.read_csv("../data/UKE.sample_annotation_v4_181samples.tsv",sep ="\t",index_col=0)
shared_genes = sorted(set(exprs.index.values))#.intersection(set(exprs_dasl.index.values)))


bg_gene_names = [rename_gene(x) for x in shared_genes if len(rename_gene(x))>0]
bg_gene_names = sorted(bg_gene_names)
exprs_g_names = exprs.loc[:,:].copy()
exprs_g_names.index = [rename_gene(x,keep_not_mapped=True) for x in exprs.index.values]
exprs_g_names = exprs_g_names.loc[bg_gene_names,:]
print(len(bg_gene_names))
# Out:
# 20379

# %%
gset_dbs = ['GO_Molecular_Function_2023', 
            'GO_Biological_Process_2023',
            'Reactome_2022',
            'WikiPathway_2023_Human',
            'KEGG_2021_Human',
            'CORUM',
            'GTEx_Tissues_V8_2023',
            'CellMarker_2024',
            'Descartes_Cell_Types_and_Tissue_2021',
            'Tabula_Sapiens']

gset_stats  = {}
## download databases, extract datasets, overlap with background
for db in gset_dbs:
    gset_stats[db] = {}
    gset_db = gseapy.get_library(name=db, organism='human')
    print(db, len(gset_db.keys()))
    for gs in gset_db.keys():
        gset = gset_db[gs]
        gset_exprs = set(gset).intersection(set(bg_gene_names))
        #print(db, gs, len(gset),len(gset_exprs), gset_exprs)
        gset_stats[db][gs] = gset_exprs
# Out:
# GO_Molecular_Function_2023 1147
# GO_Biological_Process_2023 5406
# Reactome_2022 1816
# WikiPathway_2023_Human 801
# KEGG_2021_Human 320
# CORUM 1658
# GTEx_Tissues_V8_2023 511
# CellMarker_2024 1692
# Descartes_Cell_Types_and_Tissue_2021 172
# Tabula_Sapiens 469

# %%
from openpyxl import load_workbook

xls_flie = 'tables/_S4_RSF_biclusters_ORA.xlsx'

with pd.ExcelWriter(xls_flie, engine='openpyxl') as writer:
    if not os.path.exists(xls_flie):
        pd.DataFrame().to_excel(writer, engine='openpyxl', sheet_name= "description")

    ora_results = []
    for b in sele_bics_ids:
        gene_list = sorted(uke_bics.loc[b,"genes"])
        #gene_list = sorted(dasl_bics.loc[b,"genes"])
        print(gene_list)
        gp_output = gseapy.enrichr(gene_list=gene_list,
                                   gene_sets=gset_dbs,
                                   organism="human",
                                   background=bg_gene_names,
                                   outdir="gseapy/",
                                   no_plot=True
                                  )
        res = gp_output.results
        res = res.loc[res["Adjusted P-value"]<0.05,:].copy()

        res['genes'] =  res['Genes'].apply(lambda x: " ".join(sorted(x.split(";"))))
        try:
            res["db_gset_size"] = res.apply(lambda x: len(gset_stats[x["Gene_set"]][x["Term"]]),axis=1)
        except:
            res["db_gset_size"] = np.nan
        res["overlap_size"] =  res['Genes'].apply(lambda x: len(sorted(x.split(";"))))

        res['bicluster_id'] = b
        cols = ['bicluster_id','Gene_set', 'Term',  'P-value', 'Adjusted P-value', 'Odds Ratio', 'Combined Score',
                'overlap_size', 'db_gset_size', 'genes']
        res = res.loc[res["overlap_size"]>1,cols]
        res["Gene_set_collection"] = res["Gene_set"]
        res["gene_set_name"] = res["Term"]

        cols = ['Gene_set_collection', 'gene_set_name', 'P-value', 'Adjusted P-value', 'Odds Ratio', 'overlap_size', 'genes']
        res = res.loc[:,cols].drop_duplicates(subset=["genes","Gene_set_collection"])
        res = res.sort_values(by = ["Adjusted P-value","Odds Ratio","genes","Gene_set_collection"],
                                ascending  = [True, False,True, True])
        res["bicluster"] = b
        ora_results.append(res.loc[:,cols+["bicluster"]].copy())
        res = res.set_index("gene_set_name")
        print( "bic."+str(b), "genes in query set:",len(gene_list),"DB gene sets passed:", res.shape[0])
        res.to_excel(writer, engine='openpyxl', sheet_name= "bic."+str(b))

ora_results = pd.concat(ora_results)
ora_results
# Out:
# ['ENSG00000249721', 'LINC00491', 'LINC01456', 'PTH2R', 'SLCO6A1']
# bic.84 genes in query set: 5 DB gene sets passed: 0
# ['ADIPOQ', 'CADM3-AS1', 'CIDEA', 'CIDEC', 'CYP4F24P', 'FABP4', 'IGLON5', 'LINC01096', 'MIR646HG', 'NKX2-5', 'RERGL', 'TRARG1']
# bic.130 genes in query set: 12 DB gene sets passed: 25
# ['ADAM12', 'ADAMTS12', 'ALPK2', 'C1QTNF6', 'C5orf46', 'CALB2', 'CASC18', 'CCL11', 'CHRNA1', 'CHSY3', 'COL11A1', 'CORIN', 'CSMD2', 'CTSK', 'DPP10', 'EDIL3', 'ENSG00000222022', 'ENSG00000222032', 'ENSG00000232821', 'ENSG00000236841', 'ENSG00000254605', 'ENSG00000256654', 'ENSG00000265579', 'EPYC', 'GALNT5', 'GREM1', 'INHBA-AS1', 'ISL2', 'KCNA1', 'KIF26B-AS1', 'LINC00922', 'LINC00968', 'LINC01429', 'LINC01561', 'LINC01614', 'LINC01638', 'LINC01929', 'LINC02544', 'LNCAROD', 'LRRC15', 'MEGF10', 'MMP11', 'MMP13', 'NETO1', 'NTM', 'NTMT2', 'OMD', 'PLAU', 'PRRX1', 'RFX8', 'RPL29P19', 'RTL3', 'SERPINB7', 'SRPX2', 'TENM3', 'TMEM158', 'VCAN', 'XIRP1']
# bic.70 genes in query set: 58 DB gene sets passed: 31
# ['ENSG00000261026', 'ENSG00000285848', 'NR4A1', 'NR4A3', 'PRR9', 'TEX26-AS1']
# bic.90 genes in query set: 6 DB gene sets passed: 4
# ['ENSG00000279712', 'EPIC1', 'KASH5', 'LINC00898', 'LINC01854', 'LINC01992', 'MAGEA10', 'MAGEA9B', 'OR56A3']
# bic.109 genes in query set: 9 DB gene sets passed: 0
# ['FOXD1', 'PAX6', 'ZIC2', 'ZIC3', 'ZIC5']
# bic.41 genes in query set: 5 DB gene sets passed: 20
# ['ENSG00000272763', 'GATA2-AS1', 'HOXB-AS4', 'HOXB8', 'HOXB9']
# bic.95 genes in query set: 5 DB gene sets passed: 2
#             Gene_set_collection  \
# 264        GTEx_Tissues_V8_2023
# 235      WikiPathway_2023_Human
# 274        GTEx_Tissues_V8_2023
# 333             CellMarker_2024
# 215               Reactome_2022
# ..                          ...
# 34   GO_Biological_Process_2023
# 57   GO_Biological_Process_2023
# 75                Reactome_2022
# 0    GO_Molecular_Function_2023
# 17   GO_Biological_Process_2023
#
#                                          gene_set_name       P-value  \
# 264            Breast - Mammary Tissue Female 30-39 Up  1.064448e-07
# 235              Familial Partial Lipodystrophy WP5102  5.652806e-07
# 274         Adipose - Visceral (Omentum) Male 50-59 Up  1.070771e-05
# 333               Adipogenic Cell Adipose Tissue Mouse  3.176126e-06
# 215          Lipid Particle Organization R-HSA-8964572  4.762654e-06
# ..                                                 ...           ...
# 34   Negative Regulation Of Nucleic Acid-Templated ...  4.337495e-03
# 57   Positive Regulation Of Transcription By RNA Po...  1.605203e-02
# 75                 Developmental Biology R-HSA-1266738  1.656095e-02
# 0             Double-Stranded DNA Binding (GO:0003690)  4.119093e-03
# 17   Regulation Of DNA-templated Transcription (GO:...  3.824481e-02
#
#      Adjusted P-value   Odds Ratio  overlap_size                     genes  \
# 264          0.000002   133.473684             4  ADIPOQ CIDEA CIDEC FABP4
# 235          0.000012   260.743590             3         CIDEA CIDEC FABP4
# 274          0.000067    92.652968             3        ADIPOQ CIDEA FABP4
# 333          0.000092  1357.400000             2               CIDEC FABP4
# 215          0.000095  1018.000000             2               CIDEA CIDEC
# ..                ...          ...           ...                       ...
# 34           0.011244    30.770062             2                FOXD1 ZIC2
# 57           0.019967    15.310588             2                 PAX6 ZIC3
# 75           0.020364    15.051698             2                 PAX6 ZIC3
# 0            0.011765    36.586716             2               HOXB8 HOXB9
# 17           0.040699    10.830430             2               HOXB8 HOXB9
#
#      bicluster
# 264        130
# 235        130
# 274        130
# 333        130
# 215        130
# ..         ...
# 34          41
# 57          41
# 75          41
# 0           95
# 17          95
#
# [82 rows x 8 columns]

# %%
ora_results.loc[ora_results["bicluster"]==90,:]
# Out:
#            Gene_set_collection  \
# 0   GO_Molecular_Function_2023
# 15  GO_Biological_Process_2023
# 84               Reactome_2022
# 98      WikiPathway_2023_Human
#
#                                         gene_set_name       P-value  \
# 0   Nuclear Glucocorticoid Receptor Binding (GO:00...  8.089309e-07
# 15  Regulation Of Type B Pancreatic Cell Prolifera...  2.889565e-07
# 84  Nuclear Receptor Transcription Pathway R-HSA-3...  3.529505e-05
# 98                      VEGFA VEGFR2 Signaling WP3888  2.532713e-03
#
#     Adjusted P-value   Odds Ratio  overlap_size        genes  bicluster
# 0           0.000012  3394.333333             2  NR4A1 NR4A3         90
# 15          0.000020  6789.666667             2  NR4A1 NR4A3         90
# 84          0.000494   423.416667             2  NR4A1 NR4A3         90
# 98          0.011175    47.160757             2  NR4A1 NR4A3         90

# %%
import pandas as pd


def make_topk_hits_table(ora_results: pd.DataFrame, k: int) -> pd.DataFrame:
    """
    Reformat an ORA results table so each row corresponds to one bicluster and
    contains the top-k most significant hits ranked by minimum adjusted p-value.

    Parameters
    ----------
    ora_results : pd.DataFrame
        Input dataframe with at least these columns:
        - Gene_set_collection
        - gene_set_name
        - Adjusted P-value
        - Odds Ratio
        - gene
        - bicluster

        Optional columns such as P-value, overlap_size are ignored here.

    k : int
        Number of top hits to keep per bicluster.

    Returns
    -------
    pd.DataFrame
        Dataframe with columns:
        - bicluster
        - top-k hits
    """
    required_cols = [
        "Gene_set_collection",
        "gene_set_name",
        "Adjusted P-value",
        "Odds Ratio",
        "genes",
        "bicluster",
    ]
    missing = [c for c in required_cols if c not in ora_results.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    if not isinstance(k, int) or k <= 0:
        raise ValueError("k must be a positive integer")

    df = ora_results.copy()

    # Ensure numeric sorting/formatting works
    df["Adjusted P-value"] = pd.to_numeric(df["Adjusted P-value"], errors="coerce")
    df["Odds Ratio"] = pd.to_numeric(df["Odds Ratio"], errors="coerce")

    def format_hit(row) -> str:
        adj_p = f"{row['Adjusted P-value']:.2e}" if pd.notna(row["Adjusted P-value"]) else "NA"
        odds_ratio = f"{row['Odds Ratio']:.1f}" if pd.notna(row["Odds Ratio"]) else "NA"
        genes = str(row["genes"]) if pd.notna(row["genes"]) else ""

        return (
            f"{row['gene_set_name']} ({row['Gene_set_collection']}): "
            f"{genes}; "
            f"adj.p={adj_p}; "
            f"OR={odds_ratio}"
        )

    # Sort within bicluster by adjusted p-value ascending
    df_sorted = df.sort_values(
            by=["bicluster", "overlap_size", "Odds Ratio", "Adjusted P-value",],
            ascending=[True, False, False, True],
            kind="mergesort"
    )

    # Keep top-k hits per bicluster
    topk = df_sorted.groupby("bicluster", group_keys=False).head(k).copy()

    # Format each hit as requested
    topk["formatted_hit"] = topk.apply(format_hit, axis=1)

    # Collapse hits into newline-separated strings
    result = (
        topk.groupby("bicluster", as_index=False)["formatted_hit"]
        .agg("\n".join)
        .rename(columns={"formatted_hit": "top-k hits"})
    )

    return result

k = 5
top_hits_df = make_topk_hits_table(ora_results, k=k)
print(top_hits_df.head())
top_hits_df.to_csv("tables/S4a_RSF_biclusters_ORA_top"+str(k)+".tsv",sep="\t")
ora_results.to_csv("tables/S4b_RSF_biclusters_ORA_full.tsv",sep="\t")
ora_results
top_hits_df.head()
# Out:
#    bicluster                                         top-k hits
# 0         41  Cis-Regulatory Region Sequence-Specific DNA Bi...
# 1         70  Endopeptidase Activity (GO:0004175) (GO_Molecu...
# 2         90  Regulation Of Type B Pancreatic Cell Prolifera...
# 3         95  Double-Stranded DNA Binding (GO:0003690) (GO_M...
# 4        130  Breast - Mammary Tissue Female 30-39 Up (GTEx_...
#    bicluster                                         top-k hits
# 0         41  Cis-Regulatory Region Sequence-Specific DNA Bi...
# 1         70  Endopeptidase Activity (GO:0004175) (GO_Molecu...
# 2         90  Regulation Of Type B Pancreatic Cell Prolifera...
# 3         95  Double-Stranded DNA Binding (GO:0003690) (GO_M...
# 4        130  Breast - Mammary Tissue Female 30-39 Up (GTEx_...

# %%
# previously reported biomarkers
prev_bm = ["ENSG00000112715", "ENSG00000173511", "ENSG00000150630", "ENSG00000128052", 
           "ENSG00000261371", "ENSG00000099250", "ENSG00000105976", "ENSG00000283736", 
           "ENSG00000091879", "ENSG00000133048", "ENSG00000154188", "ENSG00000120156", 
           "ENSG00000102854", "ENSG00000037280", "ENSG00000229314", "ENSG00000228278", 
           "ENSG00000181143"]
[rename_gene(x, keep_not_mapped=True) for x in prev_bm]
# Out:
# ['VEGFA',
#  'VEGFB',
#  'VEGFC',
#  'KDR',
#  'PECAM1',
#  'NRP1',
#  'MET',
#  'ENSG00000283736',
#  'ANGPT2',
#  'CHI3L1',
#  'ANGPT1',
#  'TEK',
#  'MSLN',
#  'FLT4',
#  'ORM1',
#  'ORM2',
#  'MUC16']

# %% [markdown]
# # replication of biclusters in proteomics data

# %%
# replace bic.84 genes found in UKE with 13-gene signature
bic84 = uke_bics.loc[84,"genes"]
bic84_13genes = ["PAEP", "CLDN6", "COL9A1", "CTCFL", "DPEP3", 
         "DSCR8", "GNGT1", "LINC01101", "LRRTM4", "MAGEA10", 
         "PTH2R", "SLCO1A2", "SPINK5"]
uke_bics2 = uke_bics.loc[sele_bics_ids, :].copy()
uke_bics2.loc[84,["genes"]]  = [set(bic84_13genes)]
uke_bics2.loc[84,["genes_down"]] = [uke_bics2.loc[84,"genes"].difference(set(["PAEP"]))]
uke_bics2.loc[84,["genes_up"]] = [set(["PAEP"])]
uke_bics2.loc[84,"n_genes"] = 13 
uke_bics2
# Out:
#           SNR  n_genes  n_samples  \
# id
# 84   1.660116       13        106
# 130  1.572471       12         83
# 70   1.691438       58        105
# 90   1.649042        6         91
# 109  1.605888        9         80
# 41   1.789489        5         84
# 95   1.627854        5         93
#
#                                                  genes  \
# id
# 84   {DPEP3, PTH2R, PAEP, MAGEA10, GNGT1, SPINK5, S...
# 130  {ADIPOQ, RERGL, CYP4F24P, NKX2-5, CIDEC, TRARG...
# 70   {ENSG00000254605, RFX8, GALNT5, C1QTNF6, CTSK,...
# 90   {NR4A3, NR4A1, ENSG00000261026, PRR9, ENSG0000...
# 109  {LINC00898, MAGEA10, ENSG00000279712, MAGEA9B,...
# 41                     {FOXD1, ZIC5, ZIC3, PAX6, ZIC2}
# 95   {HOXB9, HOXB8, GATA2-AS1, HOXB-AS4, ENSG000002...
#
#                                                samples  \
# id
# 84   {T0315, T5984, T3346, T6832, T6881, T6381, T67...
# 130  {T6587, T5984, T6881, T6726, T6711, T3515, T59...
# 70   {T0315, T6373, T3346, T6832, T6985, T6691, T69...
# 90   {T6587, T5984, T6881, T0646, T6932, T6963, T35...
# 109  {T0315, T6373, T6587, T0646, T6381, T6726, T66...
# 41   {T0315, T6373, T3346, T6832, T6691, T6932, T23...
# 95   {T0315, T6373, T6726, T6985, T6691, T3884, T63...
#
#                                               genes_up  \
# id
# 84                                              {PAEP}
# 130  {ADIPOQ, RERGL, CYP4F24P, NKX2-5, CIDEC, TRARG...
# 70                                                  {}
# 90   {NR4A3, NR4A1, ENSG00000261026, PRR9, ENSG0000...
# 109  {LINC00898, MAGEA10, ENSG00000279712, MAGEA9B,...
# 41                     {FOXD1, ZIC5, ZIC3, PAX6, ZIC2}
# 95   {HOXB9, HOXB8, GATA2-AS1, HOXB-AS4, ENSG000002...
#
#                                             genes_down  \
# id
# 84   {DPEP3, PTH2R, MAGEA10, GNGT1, SPINK5, SLCO1A2...
# 130                                                 {}
# 70   {ENSG00000254605, RFX8, GALNT5, C1QTNF6, CTSK,...
# 90                                                  {}
# 109                                                 {}
# 41                                                  {}
# 95                                                  {}
#
#                                           gene_indexes  \
# id
# 84                 {20516, 20699, 10287, 14040, 19323}
# 130  {11777, 17409, 14755, 4262, 11144, 21036, 1774...
# 70   {17281, 8324, 9349, 6534, 7556, 23048, 11402, ...
# 90              {4230, 9645, 21108, 8438, 14202, 2779}
# 109  {20772, 18215, 2055, 5324, 3118, 2126, 19504, ...
# 41                  {12706, 21515, 16824, 15067, 2877}
# 95                   {13986, 20967, 14830, 7383, 9406}
#
#                                         sample_indexes direction  \
# id
# 84   {0, 1, 2, 3, 5, 6, 7, 9, 17, 21, 22, 23, 25, 3...      DOWN
# 130  {3, 5, 7, 10, 26, 50, 55, 56, 64, 67, 68, 72, ...        UP
# 70   {4, 6, 8, 9, 11, 12, 13, 14, 17, 18, 20, 21, 2...      DOWN
# 90   {1, 3, 5, 10, 19, 38, 42, 44, 45, 47, 51, 53, ...        UP
# 109  {6, 8, 10, 21, 27, 29, 30, 31, 32, 33, 45, 48,...        UP
# 41   {3, 5, 6, 7, 9, 11, 12, 13, 21, 22, 23, 24, 34...        UP
# 95   {5, 6, 7, 12, 27, 28, 31, 33, 34, 35, 37, 49, ...        UP
#
#      detected_n_times                                                ids
# id
# 84                 10  seed=107473_199 seed=116739_14 seed=146316_47 ...
# 130                10  seed=107473_40 seed=116739_73 seed=146316_50 s...
# 70                 18  seed=107473_99 seed=116739_108 seed=116739_76 ...
# 90                 10  seed=107473_91 seed=116739_116 seed=146316_127...
# 109                10  seed=107473_81 seed=116739_103 seed=146316_78 ...
# 41                 10  seed=107473_21 seed=116739_30 seed=146316_62 s...
# 95                 10  seed=107473_92 seed=116739_38 seed=146316_142 ...

# %%
annot
# Out:
#            patient_id  tumor_id  bevacizumab  standard   age  FIGO_I-IIIB  \
# sample_id
# T0063               1        63            0         1  53.0            0
# T0096               2        96            0         1  43.0            0
# T0294               4       294            0         1  45.0            1
# T0305               5       305            0         1  53.0            0
# T0315               6       315            0         1  55.0            0
# ...               ...       ...          ...       ...   ...          ...
# T6993             207      6993            1         0  55.0            0
# T6995             208      6995            1         0  65.0            0
# T6999             209      6999            1         0  54.0            0
# T7001             210      7001            0         1  57.0            0
# T7003             211      7003            1         0  73.0            0
#
#            FIGO_IIIC  FIGO_IV  OP_0  OP_1  OP_2  OS_time  OS_event  PFS_time  \
# sample_id
# T0063              1        0     0     1     0     39.0       1.0       8.0
# T0096              1        0     1     0     0     61.0       1.0      59.0
# T0294              0        0     1     0     0    142.0       0.0     142.0
# T0305              1        0     0     1     0    176.0       0.0     176.0
# T0315              1        0     1     0     0    176.0       0.0     176.0
# ...              ...      ...   ...   ...   ...      ...       ...       ...
# T6993              1        0     0     1     0     36.0       0.0      36.0
# T6995              1        0     1     0     0     27.0       0.0      16.0
# T6999              1        0     1     0     0     58.0       0.0      58.0
# T7001              1        0     1     0     0     16.0       1.0      16.0
# T7003              1        0     0     0     1     24.0       1.0      14.0
#
#            PFS_event
# sample_id
# T0063            1.0
# T0096            1.0
# T0294            0.0
# T0305            0.0
# T0315            0.0
# ...              ...
# T6993            0.0
# T6995            1.0
# T6999            0.0
# T7001            0.0
# T7003            1.0
#
# [181 rows x 15 columns]

# %%
df1 = pd.read_csv("/home/olya/TUM/DESMOND/DESMOND2/OV_cancer_final/R1_GM/Hu_2020_proteomics/Hu.prot_log2.tsv", sep ="\t",index_col=0)
df1["gene"] = df1.index
df1 = df1.groupby("gene").agg("sum")
plt.figure(figsize =(5,2))
tmp = plt.hist(df1.loc["CTCFL",:],bins=10)
print(df1.shape)
tmp = plt.xlabel("CTCFL protein log-intensity")
tmp = plt.ylabel("samples")
tmp = plt.title("Hu et al., 2020")
# Out:
# (5915, 106)

# %%
df2 = pd.read_csv("/home/olya/TUM/DESMOND/DESMOND2/OV_cancer_final/R1_GM/McDermott_2020_proteomics/mcDermott_2020.prot_log2.tsv", sep ="\t",index_col=0)
df2["gene"] = df2.index
df2 = df2.groupby("gene").agg("sum")

plt.figure(figsize =(5,2))
tmp = plt.hist(df2.loc["CTCFL",:],bins=10)
print(df2.shape)
tmp = plt.xlabel("CTCFL protein log-intensity")
tmp = plt.ylabel("samples")
tmp = plt.title("McDermott et al., 2020")
# Out:
# (10077, 103)

# %%
ax = df1.plot.box(figsize =(14,3))
df1.median().min() ,df1.median().max()
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_ylim(-5, 5)
ax.set_xlabel("log-intensities per sample (Hu et al., 2020)")
# Out:
# Text(0.5, 0, 'log-intensities per sample (Hu et al., 2020)')

# %%
# replace NA with smallest values in df
na_val = df2.min().min()
df2 = df2.fillna(na_val)
ax=df2.plot.box(figsize =(14,3))
df2.median().min() ,df2.median().max()
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_ylim(-5, 5)
ax.set_xlabel("log-intensities per sample (McDermott et al., 2020)")
# Out:
# Text(0.5, 0, 'log-intensities per sample (McDermott et al., 2020)')

# %%
hu_bics, gs_stat_hu = make_similar_biclusters(uke_bics2,
                                                    prepare_input_matrix(df1,ceiling=3),
                                                    seed=analysis_seed,
                                              min_snr=0.5)
hu_bics = hu_bics.sort_values(["n_genes","SNR"],ascending=[False,False])
hu_bics
# Out:
#          SNR direction                   gene_indexes  \
# 70  1.564068        UP  {641, 3467, 1004, 5594, 3739}
#
#                                 genes genes_down  \
# 70  {PLAU, OMD, CALB2, COL11A1, VCAN}         {}
#
#                              genes_up n_genes n_samples  \
# 70  {PLAU, OMD, CALB2, COL11A1, VCAN}       5        49
#
#                                        sample_indexes  \
# 70  {0, 2, 6, 7, 10, 12, 13, 17, 19, 20, 24, 25, 2...
#
#                                               samples
# 70  {SPL 044, SPL 010, SPL 013, SPL 076, SPL 068, ...

# %%
#Hu: bic.70 - 10, bic. 84 - 1, bic130 - 1; in total 12
#mcDermott: bic70 - 21, bic 84 - 6, bic130 - 2, bic109 - 1, and bic95 - 1; in total 31
12/uke_bics2["n_genes"].sum(), 31/uke_bics2["n_genes"].sum()
# Out:
# (0.1111111111111111, 0.28703703703703703)

# %%
mcd_bics, gs_stat_mcd = make_similar_biclusters(uke_bics2,
                                                    prepare_input_matrix(df2),
                                                    seed=analysis_seed,
                                                 min_snr=0.5)
mcd_bics.sort_values("n_genes",ascending=False)
# Out:
#                                         sample_indexes n_samples  \
# 70   {1, 5, 6, 7, 11, 12, 13, 14, 15, 16, 18, 19, 2...        46
# 84   {2, 5, 10, 12, 13, 16, 18, 20, 21, 23, 24, 25,...        40
# 130  {0, 2, 3, 4, 8, 24, 25, 27, 28, 30, 34, 35, 36...        51
#
#                                                  genes n_genes direction  \
# 70   {PLAU, OMD, NTM, GALNT5, ADAMTS12, LRRC15, CTS...      14      DOWN
# 84                                      {CTCFL, CLDN6}       2        UP
# 130                                    {ADIPOQ, FABP4}       2        UP
#
#                                                samples  \
# 70   {C17OV001, C02OV022, C11OV002, C17OV002, N01OV...
# 84   {C04OV040, C04OV063, N17OV002, C17OV018, C02OV...
# 130  {C04OV063, C17OV001, N17OV002, C04OV028, N01OV...
#
#                                           gene_indexes         genes_up  \
# 70   {4641, 2022, 1769, 1610, 6380, 3247, 6767, 580...               {}
# 84                                        {1656, 1992}   {CTCFL, CLDN6}
# 130                                        {2858, 195}  {ADIPOQ, FABP4}
#
#                                             genes_down       SNR
# 70   {PLAU, OMD, NTM, GALNT5, ADAMTS12, LRRC15, CTS...  1.703723
# 84                                                  {}  1.334655
# 130                                                 {}  1.434444

# %%
hu_annot = pd.read_csv("/home/olya/TUM/DESMOND/DESMOND2/OV_cancer_final/R1_GM/Hu_2020_proteomics/Hu.sample_info.tsv",index_col=0,sep ="\t")
mcd_annot = pd.read_csv("/home/olya/TUM/DESMOND/DESMOND2/OV_cancer_final/R1_GM/McDermott_2020_proteomics/mcDermott_2020.sample_info.tsv",index_col=0,sep ="\t")
#mcd_annot.head(10).T

# %%
df3= pd.read_csv("/home/olya/TUM/DESMOND/DESMOND2/OV_cancer_final/R1_GM/McDermott_2020_proteomics/mcDermott_2020.exprs_FPKM.tsv",index_col=0,sep ="\t")
df3["gene"] = df3.index
df3 = df3.groupby("gene").agg("mean")
df3 = df3.applymap(lambda x: np.log2(x+1))

tmp = plt.hist(df3.loc["CTCFL",:],bins=10)
print(df2.shape)
tmp = plt.xlabel("log2 FPKM")
tmp = plt.ylabel("samples")
tmp = plt.title("CTCFL gene expression (McDermott et al., 2020)")
mcde_bics, gs_stat_mcde = make_similar_biclusters(uke_bics2,
                                                    prepare_input_matrix(df3),
                                                    seed=analysis_seed,
                                                 min_snr=0.25)
mcde_bics.sort_values("n_genes",ascending=False)
# Out:
# (10077, 103)
#                                         sample_indexes n_samples  \
# 70   {3, 5, 6, 9, 11, 12, 13, 14, 15, 16, 18, 19, 2...        48
# 84   {4, 5, 7, 13, 14, 15, 16, 18, 19, 21, 22, 26, ...        48
# 130  {0, 2, 4, 7, 23, 24, 26, 27, 29, 30, 33, 34, 3...        32
# 41       {2, 34, 4, 5, 42, 77, 78, 19, 86, 23, 56, 94}        12
# 90   {9, 12, 24, 25, 26, 43, 47, 51, 55, 56, 61, 63...        19
# 109                     {64, 2, 3, 67, 39, 40, 47, 79}         8
# 95   {2, 5, 10, 12, 22, 23, 26, 30, 34, 35, 41, 50,...        30
#
#                                                  genes n_genes direction  \
# 70   {C5orf46, LINC00968, CASC18, C1QTNF6, MMP13, C...      35      DOWN
# 84   {CLDN6, GNGT1, LINC01101, SPINK5, CTCFL, SLCO1...      11      DOWN
# 130   {IGLON5, RERGL, CIDEA, LINC01096, FABP4, ADIPOQ}       6        UP
# 41                     {PAX6, ZIC3, ZIC5, FOXD1, ZIC2}       5      BOTH
# 90                                      {NR4A1, NR4A3}       2        UP
# 109                                {LINC00898, OR56A3}       2        UP
# 95                                      {HOXB8, HOXB9}       2        UP
#
#                                                samples  \
# 70   {04OV058, 13OV003, 01OV019, 02OV022, 04OV017, ...
# 84   {13OV003, 02OV022, 13OV004, 04OV017, 26OV008, ...
# 130  {04OV058, 04OV013, 04OV037, 04OV036, 04OV012, ...
# 41   {01OV019, 02OV044, 01OV026, 26OV008, 04OV005, ...
# 90   {04OV058, 04OV012, 17OV025, 26OV002, 26OV009, ...
# 109  {04OV040, 17OV017, 04OV053, 26OV009, 01OV018, ...
# 95   {01OV019, 26OV008, 04OV004, 02OV006, 04OV041, ...
#
#                                           gene_indexes  \
# 70   {1796, 260, 8716, 3345, 18708, 10647, 2973, 28...
# 84   {16320, 8803, 3080, 3304, 6223, 3600, 15793, 4...
# 130               {7297, 3015, 341, 14329, 8798, 4991}
# 41                  {18977, 5700, 12650, 18974, 18975}
# 90                                      {11965, 11967}
# 109                                      {12370, 8703}
# 95                                        {7003, 7004}
#
#                                              genes_up  \
# 70                                                 {}
# 84                                                 {}
# 130  {IGLON5, CIDEA, LINC01096, ADIPOQ, FABP4, RERGL}
# 41                          {FOXD1, ZIC5, ZIC3, ZIC2}
# 90                                     {NR4A1, NR4A3}
# 109                               {LINC00898, OR56A3}
# 95                                     {HOXB8, HOXB9}
#
#                                             genes_down       SNR
# 70   {C5orf46, LINC00968, CASC18, C1QTNF6, MMP13, C...  1.841581
# 84   {CLDN6, LINC01101, GNGT1, SPINK5, SLCO1A2, COL...  1.560687
# 130                                                 {}  1.393016
# 41                                              {PAX6}  1.713227
# 90                                                  {}  1.920894
# 109                                                 {}  1.735815
# 95                                                  {}  1.792767

# %%
from unpast.utils.figs import draw_heatmap2

fs = 14

fig = draw_heatmap2(prepare_input_matrix(df3), mcde_bics,
              bicluster_colors="redblue",
              figsize = (10,7.5), 
              dendrogram_ratio=(0.01,0.01),
              colors_ratio=(0.02/10*7.5,0.02),
              bic_prefix = "b. ",
              legend_n_cols=0,
              no_cbar=True,
              col_labels = False,
              row_labels = True,
              highlight_row_labels=sorted(bic84_13genes),
                no_row_colors = False,cluster_rows=False
             )
ax = fig[0].ax_heatmap
tmp = ax.set_xlabel("McDermott et al., 2020, log2(FPKM+1), n=%s samples"%annot.shape[0], fontsize=fs)
plt.show()

# %%
gs_stat_hu
# Out:
#                                                  genes n_genes  \
# 84   {CLDN6, PAEP, GNGT1, LINC01101, SPINK5, SLCO1A...      13
# 130  {MIR646HG, IGLON5, RERGL, CYP4F24P, TRARG1, CI...      12
# 70   {LINC00968, ENSG00000254605, C5orf46, ENSG0000...      58
# 90   {NR4A1, ENSG00000261026, PRR9, TEX26-AS1, ENSG...       6
# 109  {KASH5, MAGEA9B, OR56A3, MAGEA10, EPIC1, LINC0...       9
# 41                     {ZIC5, ZIC3, PAX6, FOXD1, ZIC2}       5
# 95   {HOXB8, ENSG00000272763, HOXB-AS4, GATA2-AS1, ...       5
#
#                                         genes_measured n_genes_measured  \
# 84                                             [CTCFL]                1
# 130                                            [FABP4]                1
# 70   [CALB2, COL11A1, GALNT5, LRRC15, MMP11, OMD, P...               10
# 90                                                  []                0
# 109                                                 []                0
# 41                                                  []                0
# 95                                                  []                0
#
#                                 genes2 n_genes2       SNR      SNR2
# 84                                 NaN      NaN       NaN       NaN
# 130                                NaN      NaN       NaN       NaN
# 70   {OMD, PLAU, CALB2, VCAN, COL11A1}        5  1.691438  1.564068
# 90                                 NaN      NaN       NaN       NaN
# 109                                NaN      NaN       NaN       NaN
# 41                                 NaN      NaN       NaN       NaN
# 95                                 NaN      NaN       NaN       NaN

# %%
gs_stat_mcd
# Out:
#                                                  genes n_genes  \
# 84   {CLDN6, PAEP, GNGT1, LINC01101, SPINK5, SLCO1A...      13
# 130  {MIR646HG, IGLON5, RERGL, CYP4F24P, TRARG1, CI...      12
# 70   {LINC00968, ENSG00000254605, C5orf46, ENSG0000...      58
# 90   {NR4A1, ENSG00000261026, PRR9, TEX26-AS1, ENSG...       6
# 109  {KASH5, MAGEA9B, OR56A3, MAGEA10, EPIC1, LINC0...       9
# 41                     {ZIC5, ZIC3, PAX6, FOXD1, ZIC2}       5
# 95   {HOXB8, ENSG00000272763, HOXB-AS4, GATA2-AS1, ...       5
#
#                                         genes_measured n_genes_measured  \
# 84        [CLDN6, CTCFL, DPEP3, MAGEA10, PAEP, SPINK5]                6
# 130                                    [ADIPOQ, FABP4]                2
# 70   [ADAM12, ADAMTS12, ALPK2, CALB2, CHSY3, COL11A...               21
# 90                                                  []                0
# 109                                          [MAGEA10]                1
# 41                                                  []                0
# 95                                             [HOXB8]                1
#
#                                                 genes2 n_genes2       SNR  \
# 84                                {CLDN6, CTCFL, PAEP}        3  1.660116
# 130                                    {FABP4, ADIPOQ}        2  1.572471
# 70   {GREM1, OMD, LRRC15, NTM, PRRX1, VCAN, ADAMTS1...       17  1.691438
# 90                                                 NaN      NaN       NaN
# 109                                                NaN      NaN       NaN
# 41                                                 NaN      NaN       NaN
# 95                                                 NaN      NaN       NaN
#
#          SNR2
# 84   1.354865
# 130  1.434444
# 70   1.694223
# 90        NaN
# 109       NaN
# 41        NaN
# 95        NaN

# %%
set(df1.index.values).intersection(set(bic84_13genes))
# Out:
# {'CTCFL'}

# %%
sorted(set(df2.index.values).intersection(set(bic84_13genes)))
# Out:
# ['CLDN6', 'CTCFL', 'DPEP3', 'MAGEA10', 'PAEP', 'SPINK5']

# %%
from unpast.utils.figs import draw_heatmap2

b = hu_bics
fs = 14

fig = draw_heatmap2(prepare_input_matrix(df1), b,
                    #annot=uke_subt.loc[:,["subtype","Bentink"]],
                    #color_dict=color_dict,
              bicluster_colors="redblue",
              figsize = (5,4), 
              dendrogram_ratio=(0.01,0.01),
              colors_ratio=(0.04/5*4, 0.04),
              bic_prefix = "b. ",
              legend_n_cols=0,
              no_cbar=True,
              col_labels = False,
              row_labels = True,
              highlight_row_labels=sorted(bic84_13genes),
                no_row_colors = True,
                    cluster_rows=False
             )
ax = fig[0].ax_heatmap
tmp = ax.set_xlabel("Hu et al., 2020; n=%s samples"%df1.shape[1], fontsize=fs)
plt.show()

# %%
from unpast.utils.figs import draw_heatmap2

fs = 14

fig = draw_heatmap2(prepare_input_matrix(df2),
                    mcd_bics,
              bicluster_colors="redblue",
              figsize = (6,4), 
              dendrogram_ratio=(0.01,0.01),
              colors_ratio=(0.04/6*4, 0.04),
              bic_prefix = "b. ",
              legend_n_cols=0,
              no_cbar=True,
              col_labels = False,
              row_labels = True,
              highlight_row_labels=sorted(bic84_13genes),
                no_row_colors = False,cluster_rows=False
             )
ax = fig[0].ax_heatmap
tmp = ax.set_xlabel("McDermott et al., 2020; n=%s samples"%df2.shape[1], fontsize=12)
plt.show()

# %%
df2_z = prepare_input_matrix(df2)
df2_z.loc[sorted(set(df2.index.values).intersection(set(bic84_13genes))),:].T.corr()
# Out:
#             CLDN6     CTCFL     DPEP3   MAGEA10      PAEP    SPINK5
# CLDN6    1.000000  0.148601  0.063746  0.101583 -0.182933  0.023202
# CTCFL    0.148601  1.000000 -0.113144  0.113093 -0.195307  0.173647
# DPEP3    0.063746 -0.113144  1.000000 -0.141077 -0.033503 -0.034461
# MAGEA10  0.101583  0.113093 -0.141077  1.000000 -0.082865  0.007197
# PAEP    -0.182933 -0.195307 -0.033503 -0.082865  1.000000  0.028255
# SPINK5   0.023202  0.173647 -0.034461  0.007197  0.028255  1.000000

# %% [markdown]
# ### Do the patients with high expression of COL9A1, also have high expression of TSP-1 and matrilin-1, and low expression of MMP-9?

# %%
gs1 = ["COL9A1","THBS1","MATN1","MMP9"]
exprs_z_rn.loc[gs1,:].T.corr()
# Out:
#           COL9A1     THBS1     MATN1      MMP9
# COL9A1  1.000000 -0.041381  0.168619  0.115958
# THBS1  -0.041381  1.000000 -0.142075  0.340413
# MATN1   0.168619 -0.142075  1.000000 -0.199540
# MMP9    0.115958  0.340413 -0.199540  1.000000

# %%
df = exprs_z_rn.loc[gs1,:].copy().T
df['COL9A1_group'] = pd.qcut(df['COL9A1'], q=2, labels=['Low','High'])

# %%
sns.pairplot(
    df,
    hue='COL9A1_group'
)

# %%
sns.lmplot(x='COL9A1', y='THBS1', data=df, hue='COL9A1_group')
sns.lmplot(x='COL9A1', y='MMP9', data=df, hue='COL9A1_group')

# %%
genes = ['THBS1', 'MATN1', 'MMP9']

long_df = df.melt(
    id_vars=['COL9A1_group'],
    value_vars=genes,
    var_name='Gene',
    value_name='Expression'
)

g = sns.catplot(
    data=long_df,
    x='COL9A1_group',
    y='Expression',
    hue='COL9A1_group',
    col='Gene',
    kind='box',
    dodge=False,
    sharey=False,
    height=4,
    aspect=0.9
)

for ax, gene in zip(g.axes.flat, genes):
    sns.stripplot(
        data=long_df[long_df['Gene'] == gene],
        x='COL9A1_group',
        y='Expression',
        color='black',
        alpha=0.45,
        size=3,
        ax=ax
    )
    if ax.legend_ is not None:
        ax.legend_.remove()

g.set_axis_labels('', 'standardized expression, UKE')
g.set_titles('{col_name}')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests

genes = ['THBS1', 'MATN1', 'MMP9']

results = []

for gene in genes:
    low = df[df['COL9A1_group'] == 'Low'][gene].dropna()
    high = df[df['COL9A1_group'] == 'High'][gene].dropna()

    u_stat, p_value = mannwhitneyu(low, high, alternative='two-sided')

    results.append({
        'Gene': gene,
        'U_stat': u_stat,
        'p_value': p_value,
        'Low_median': low.median(),
        'High_median': high.median()
    })

results_df = pd.DataFrame(results)

# Benjamini-Hochberg correction
reject, p_adj, _, _ = multipletests(results_df['p_value'], method='fdr_bh')

results_df['p_adj_BH'] = p_adj
results_df['significant_BH_0.05'] = reject
results_df["diff_of_medians"] = results_df["High_median"] - results_df["Low_median"]

print(results_df)
# Out:
#     Gene  U_stat   p_value  Low_median  High_median  p_adj_BH  \
# 0  THBS1  7226.0  0.695852   -0.016115     0.058764  0.695852
# 1  MATN1  6842.5  0.277207   -0.055490     0.096761  0.415811
# 2   MMP9  6331.0  0.043958    0.028833     0.212475  0.131873
#
#    significant_BH_0.05  diff_of_medians
# 0                False         0.074879
# 1                False         0.152251
# 2                False         0.183642

# %% [markdown]
# ### DASL

# %%
exprs_z_rn_dasl.loc[gs1,:].T.corr()
# Out:
#           COL9A1     THBS1     MATN1      MMP9
# COL9A1  1.000000 -0.131697  0.149010  0.057311
# THBS1  -0.131697  1.000000 -0.091083 -0.045708
# MATN1   0.149010 -0.091083  1.000000 -0.140042
# MMP9    0.057311 -0.045708 -0.140042  1.000000

# %%
df = exprs_z_rn_dasl.loc[gs1,:].copy().T
df['COL9A1_group'] = pd.qcut(df['COL9A1'], q=2, labels=['Low','High'])

# %%
sns.pairplot(
    df,
    hue='COL9A1_group'
)

# %%
sns.lmplot(x='COL9A1', y='THBS1', data=df, hue='COL9A1_group')
sns.lmplot(x='COL9A1', y='MMP9', data=df, hue='COL9A1_group')

# %%
genes = ['THBS1', 'MATN1', 'MMP9']

long_df = df.melt(
    id_vars=['COL9A1_group'],
    value_vars=genes,
    var_name='Gene',
    value_name='Expression'
)

g = sns.catplot(
    data=long_df,
    x='COL9A1_group',
    y='Expression',
    hue='COL9A1_group',
    col='Gene',
    kind='box',
    dodge=False,
    sharey=False,
    height=4,
    aspect=0.9
)

for ax, gene in zip(g.axes.flat, genes):
    sns.stripplot(
        data=long_df[long_df['Gene'] == gene],
        x='COL9A1_group',
        y='Expression',
        color='black',
        alpha=0.45,
        size=3,
        ax=ax
    )
    if ax.legend_ is not None:
        ax.legend_.remove()

g.set_axis_labels('', 'standardized expression, DASL')
g.set_titles('{col_name}')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests

genes = ['THBS1', 'MATN1', 'MMP9']

results = []

for gene in genes:
    low = df[df['COL9A1_group'] == 'Low'][gene].dropna()
    high = df[df['COL9A1_group'] == 'High'][gene].dropna()

    u_stat, p_value = mannwhitneyu(low, high, alternative='two-sided')

    results.append({
        'Gene': gene,
        'U_stat': u_stat,
        'p_value': p_value,
        'Low_median': low.median(),
        'High_median': high.median()
    })

results_df = pd.DataFrame(results)

# Benjamini-Hochberg correction
reject, p_adj, _, _ = multipletests(results_df['p_value'], method='fdr_bh')

results_df['p_adj_BH'] = p_adj
results_df['significant_BH_0.05'] = reject
results_df["diff_of_medians"] = results_df["High_median"] - results_df["Low_median"]
print(results_df)
# Out:
#     Gene   U_stat   p_value  Low_median  High_median  p_adj_BH  \
# 0  THBS1  19513.0  0.098772    0.226415    -0.013476  0.148159
# 1  MATN1  14273.0  0.000963   -0.354409     0.106574  0.002888
# 2   MMP9  16823.0  0.372997    0.056658     0.185188  0.372997
#
#    significant_BH_0.05  diff_of_medians
# 0                False        -0.239891
# 1                 True         0.460983
# 2                False         0.128530

# %% [markdown]
# # ORA

# %%
exprs_file = "../data/TCGA-OV_noENSG00000230417_UKEgenes.est_counts_rounded.tsv" 
exprs_tcga= pd.read_csv(exprs_file,sep ="\t",index_col=0)

# %%
# only genes presenting in both UKE and DASL are accounted
import gseapy
names = gseapy.get_library_name()

#annot = pd.read_csv("../data/UKE.sample_annotation_v4_181samples.tsv",sep ="\t",index_col=0)
shared_genes = sorted(set(exprs.index.values).intersection(set(exprs_tcga.index.values)))


bg_gene_names = [rename_gene(x) for x in shared_genes if len(rename_gene(x))>0]
bg_gene_names = sorted(bg_gene_names)
exprs_g_names = exprs.loc[:,:].copy()
exprs_g_names.index = [rename_gene(x,keep_not_mapped=True) for x in exprs.index.values]
exprs_g_names = exprs_g_names.loc[bg_gene_names,:]
print(len(bg_gene_names))
# Out:
# 20316

# %%
gset_dbs = ['GO_Molecular_Function_2023', 
            'GO_Biological_Process_2023',
            'Reactome_2022',
            'WikiPathway_2023_Human',
            'KEGG_2021_Human',
            'CORUM',
            'GTEx_Tissues_V8_2023',
            'CellMarker_2024',
            'Descartes_Cell_Types_and_Tissue_2021',
            'Tabula_Sapiens']

gset_stats  = {}
## download databases, extract datasets, overlap with background
for db in gset_dbs:
    gset_stats[db] = {}
    gset_db = gseapy.get_library(name=db, organism='human')
    print(db, len(gset_db.keys()))
    for gs in gset_db.keys():
        gset = gset_db[gs]
        gset_exprs = set(gset).intersection(set(bg_gene_names))
        #print(db, gs, len(gset),len(gset_exprs), gset_exprs)
        gset_stats[db][gs] = gset_exprs

# %%
def read_limma(tsv_file,exprs):
    df = pd.read_csv(tsv_file,sep ="\t",index_col=0)
    cols = list(df.columns.values)
    df["gene"] = df.index
    df["gene"] = df["gene"].apply(lambda x: rename_gene(x))
    df = df.loc[:,["gene"]+cols]
    df = add_avg_exprs(df, exprs,col_name = "avgLog2exprs")
    df = df.sort_values(by="adj.P.Val" )
    df["rank"] = df["adj.P.Val"].rank()
    return df

def add_avg_exprs(df, exprs,col_name = "avgLog2exprs"):
    df[col_name ] = np.nan
    shared  =  sorted(set(df.index.values).intersection(set(exprs.index.values)))
    df.loc[shared,col_name ] = exprs.loc[shared ,:].mean(axis=1)
    return df

lfc = 1
p = 0.05
b = 84
df_uke = read_limma("bic"+str(b)+"_UKE181.DE.tsv",exprs)
df_dasl = read_limma("bic"+str(b)+"_DASL377.DE.tsv",exprs_dasl)
df_tcga = read_limma("bic"+str(b)+"_TCGA-OV426.DE.tsv",exprs_tcga)

#shared_genes = set(df_uke.index).intersection(set(df_tcga.index))#.intersection(set(df_dasl.index))
shared_uke_dals = set(df_uke.index).intersection(set(df_dasl.index))
shared_uke_tcga = set(df_uke.index).intersection(set(df_tcga.index))
shared_dals_tcga = set(df_tcga.index).intersection(set(df_dasl.index))
shared_genes = set(df_uke.index).union(set(df_tcga.index)).union(set(df_dasl.index))
print("shared_genes",len(shared_genes))


de_uke  =df_uke.loc[df_uke["adj.P.Val"]<p,:]
de_dasl  = df_dasl.loc[df_dasl["adj.P.Val"]<p,:]
de_tcga = df_tcga.loc[df_tcga["adj.P.Val"]<p,:]



if lfc >0:
    uke_up  = set(de_uke.loc[de_uke["logFC"]>lfc,:].index.values).intersection(shared_genes)
    dasl_up  = set(de_dasl.loc[de_dasl["logFC"]>lfc,:].index.values).intersection(shared_genes)
    tcga_up = set(de_tcga.loc[de_tcga["logFC"]>lfc,:].index.values).intersection(shared_genes)
    
    uke_down  = set(de_uke.loc[de_uke["logFC"]<-lfc,:].index.values).intersection(shared_genes)
    dasl_down  = set(de_dasl.loc[de_dasl["logFC"]<-lfc,:].index.values).intersection(shared_genes)
    tcga_down = set(de_tcga.loc[de_tcga["logFC"]<-lfc,:].index.values).intersection(shared_genes)
    
else:
    uke_up  = set(de_uke.loc[de_uke["logFC"]<lfc,:].index.values).intersection(shared_genes)
    dasl_up  = set(de_dasl.loc[de_dasl["logFC"]<lfc,:].index.values).intersection(shared_genes)
    tcga_up= set(de_tcga.loc[de_tcga["logFC"]<lfc,:].index.values).intersection(shared_genes)
    
    uke_down  = set(de_uke.loc[de_uke["logFC"]>-lfc,:].index.values).intersection(shared_genes)
    dasl_down = set(de_dasl.loc[de_dasl["logFC"]>-lfc,:].index.values).intersection(shared_genes)
    tcga_down = set(de_tcga.loc[de_tcga["logFC"]>-lfc,:].index.values).intersection(shared_genes)

de_uke = uke_up|uke_down
de_dasl = dasl_up|dasl_down
de_tcga = tcga_up|tcga_down
    
len(de_uke),len(de_dasl),len(de_tcga)
# Out:
# shared_genes 28207
# (312, 49, 683)

# %%
len(uke_down.intersection(tcga_down))
gene_list = sorted([rename_gene(x, keep_not_mapped=True) for x in uke_down.intersection(tcga_down)])
#print(len(gene_list))
print("\n".join(sorted(gene_list)))
# Out:
# ADAMTS20
# AKAP8P1
# APOA1
# ASNSP1
# BBOX1-AS1
# BMP7
# BOLL
# C12orf56
# CACNA1B
# CASC9
# CBY2
# CCDC162P
# CLDN19
# CLDN6
# CLEC18B
# CLEC18C
# CLVS1
# CNTN5
# CNTNAP5
# COL6A4P1
# COL9A1
# COL9A2
# CPLX2
# CT45A1
# CTCFL
# CXADRP3
# DEFB126
# DPEP3
# DSCR8
# ENSG00000189229
# ENSG00000206129
# ENSG00000225087
# ENSG00000226468
# ENSG00000228933
# ENSG00000229970
# ENSG00000231476
# ENSG00000231772
# ENSG00000232006
# ENSG00000232835
# ENSG00000234083
# ENSG00000234352
# ENSG00000235277
# ENSG00000235725
# ENSG00000237513
# ENSG00000237764
# ENSG00000240086
# ENSG00000248268
# ENSG00000249413
# ENSG00000249721
# ENSG00000250421
# ENSG00000250669
# ENSG00000250874
# ENSG00000250979
# ENSG00000251126
# ENSG00000251639
# ENSG00000253706
# ENSG00000254238
# ENSG00000255983
# ENSG00000256146
# ENSG00000256218
# ENSG00000256417
# ENSG00000257869
# ENSG00000258053
# ENSG00000258314
# ENSG00000258592
# ENSG00000258927
# ENSG00000259306
# ENSG00000259345
# ENSG00000259445
# ENSG00000259610
# ENSG00000259692
# ENSG00000259723
# ENSG00000260476
# ENSG00000260611
# ENSG00000263551
# ENSG00000266869
# ENSG00000267284
# ENSG00000267313
# ENSG00000267327
# ENSG00000267733
# ENSG00000268080
# ENSG00000270038
# ENSG00000270460
# ENSG00000272461
# ENSG00000279479
# ENSG00000279511
# ENSG00000279712
# EPIC1
# FABP6
# FAR2P1
# FAR2P4
# FER1L5
# FSTL4
# G2E3-AS1
# GAB4
# GABRA3
# GABRG2
# GABRR1
# GJA8
# GNGT1
# GPR158
# H2BW1
# H2BW2
# HEY2-AS1
# HTR2C
# IGSF1
# IMPG2
# ITIH6
# KCNMB2-AS1
# KIF1A
# KLF2P1
# KLF2P4
# KRTAP4-1
# LHFPL3-AS2
# LINC00470
# LINC00491
# LINC00494
# LINC00648
# LINC00649
# LINC00668
# LINC00858
# LINC00898
# LINC01101
# LINC01194
# LINC01234
# LINC01249
# LINC01297
# LINC01456
# LINC01611
# LINC01667
# LINC01748
# LINC01807
# LINC01833
# LINC01967
# LINC01980
# LINC02041
# LINC02253
# LINC02308
# LINC02315
# LINC02428
# LINC02466
# LINC02542
# LINC02562
# LINC02820
# LINC02882
# LINC02994
# LRRTM4
# MAGEA10
# MAGEA11
# MAGEA4
# MAGEA4-AS1
# MAGEC1
# MARCHF11
# MIR2052HG
# MIR3171HG
# MIR4713HG
# MKRN3
# MROH2A
# MRPS17P1
# MYOD1
# MYT1
# NIHCOLE
# NKX6-1
# NOVA1-DT
# OFCC1
# OR56A3
# OR5BH1P
# OTOG
# PADI3
# PAX3
# PCDH15
# PDCL2
# PHOX2A
# PKHD1
# POTEC
# POU6F2
# POU6F2-AS2
# PPIAP35
# PPP1R1C
# PRB3
# PSLNR
# PTH2R
# RBPJL
# RMST
# RPL7AP19
# RPL7AP21
# SAMMSON
# SELENOOLP
# SIX3
# SLC12A1
# SLC25A5P5
# SLC44A5
# SLC5A12
# SLC6A10P
# SLCO1A2
# SLCO6A1
# SPINK5
# STK31
# TAS2R38
# TCF24
# TENT5D
# TMEM132B
# TRDN
# TYRP1
# VCX
# WDR72
# XAGE2
# ZNF679
# ZNF716

# %%
g = "EPCAM"
df_uke.loc[df_uke["gene"]==g,:] # CD44
df_tcga.loc[df_tcga["gene"]==g,:] # MYC  SOX2 CD44
#df_dasl.loc[df_dasl["gene"]==g,:]
# Out:
#                   gene     logFC      CI.L      CI.R   AveExpr         t  \
# ENSG00000119888  EPCAM -0.044803 -0.215221  0.125614  8.196915 -0.516736
#
#                   P.Value  adj.P.Val         B  avgLog2exprs     rank
# ENSG00000119888  0.605607    0.71121 -7.435029  22788.323944  19308.5

# %%
df_tcga.loc[df_tcga["gene"]=="SOX2",:]

# %%
b = "84 209 genes"

# %%
from openpyxl import load_workbook

xls_flie = 'tables/XS_ORA.xlsx'

with pd.ExcelWriter(xls_flie, engine='openpyxl') as writer:
    if not os.path.exists(xls_flie):
        pd.DataFrame().to_excel(writer, engine='openpyxl', sheet_name= "description")

    gso_bic = []


    gene_list = [x for x in list(de["gene"].values) if type(x)==str]
    gp_output = gseapy.enrichr(gene_list=gene_list,
                               gene_sets=gset_dbs,
                               organism="human",
                               background=bg_gene_names,
                               outdir="gseapy/",
                               no_plot=True
                              )
    res = gp_output.results
    res = res.loc[res["Adjusted P-value"]<0.05,:].copy()

    res['genes'] =  res['Genes'].apply(lambda x: " ".join(sorted(x.split(";"))))
    try:
        res["db_gset_size"] = res.apply(lambda x: len(gset_stats[x["Gene_set"]][x["Term"]]),axis=1)
    except:
        res["db_gset_size"] = np.nan
    res["overlap_size"] =  res['Genes'].apply(lambda x: len(sorted(x.split(";"))))

    res['bicluster_id'] = b
    cols = ['bicluster_id','Gene_set', 'Term',  'P-value', 'Adjusted P-value', 'Odds Ratio', 'Combined Score',
            'overlap_size', 'db_gset_size', 'genes']
    res = res.loc[res["overlap_size"]>1,cols]
    res["Gene_set_collection"] = res["Gene_set"]
    res["gene_set_name"] = res["Term"]

    cols = ['Gene_set_collection', 'gene_set_name', 'P-value', 'Adjusted P-value', 'Odds Ratio', 'overlap_size', 'genes']
    res = res.loc[:,cols].drop_duplicates(subset=["genes","Gene_set_collection"])
    res = res.sort_values(by = ["Adjusted P-value","Odds Ratio","genes","Gene_set_collection"],
                            ascending  = [True, False,True, True])
    res["bicluster"] = b
    gso_bic.append(res.loc[:,cols].copy())
    res = res.set_index("gene_set_name")
    print( "bic."+str(b), "genes in query set:",len(gene_list),"DB gene sets passed:", res.shape[0])
    res.to_excel(writer, engine='openpyxl', sheet_name= "bic."+str(b))

gso_bic = pd.concat(gso_bic)
gso_bic
# Out:
# bic.bic.84 209 genes genes in query set: 132 DB gene sets passed: 92
#                        Gene_set_collection  \
# 1944  Descartes_Cell_Types_and_Tissue_2021
# 1945  Descartes_Cell_Types_and_Tissue_2021
# 1946  Descartes_Cell_Types_and_Tissue_2021
# 1947  Descartes_Cell_Types_and_Tissue_2021
# 1426                  GTEx_Tissues_V8_2023
# ...                                    ...
# 1966  Descartes_Cell_Types_and_Tissue_2021
# 1308                       KEGG_2021_Human
# 1778                       CellMarker_2024
# 1967  Descartes_Cell_Types_and_Tissue_2021
# 1968  Descartes_Cell_Types_and_Tissue_2021
#
#                                          gene_set_name       P-value  \
# 1944                          Visceral neurons in Lung  7.403013e-09
# 1945                          ENS neurons in Intestine  1.269649e-07
# 1946                       Metanephric cells in Kidney  2.472381e-07
# 1947                           ENS neurons in Pancreas  2.786112e-07
# 1426                              Testis Male 50-59 Up  1.805460e-08
# ...                                                ...           ...
# 1966              Vascular endothelial cells in Thymus  1.231994e-02
# 1308                  Protein digestion and absorption  2.605645e-03
# 1778  Multipotent Retinal Progenitor Cell Retina Human  1.143546e-03
# 1967  Corneal and conjunctival epithelial cells in Eye  1.352880e-02
# 1968                 CLC IL5RA positive cells in Heart  1.418225e-02
#
#       Adjusted P-value  Odds Ratio  overlap_size  \
# 1944      6.366592e-07   10.635638            12
# 1945      5.459491e-06   12.657906             9
# 1946      5.990141e-06   14.403584             8
# 1947      5.990141e-06   11.464367             9
# 1426      6.301056e-06   28.924718             7
# ...                ...         ...           ...
# 1966      4.606588e-02    3.817942             5
# 1308      4.646734e-02    7.477307             4
# 1778      4.831483e-02   51.735897             2
# 1967      4.847819e-02    3.232569             6
# 1968      4.878694e-02   11.927219             2
#
#                                                   genes
# 1944  CDH6 CNTN5 CNTNAP5 FXYD7 GABRA3 OLFM1 PHOX2A P...
# 1945  CNTN5 CNTNAP5 DLX3 INA LIX1 OLFM1 PHOX2A PTPRR...
# 1946  ADAMTS20 CDH6 CLEC18C KIF1A LRP2 PCDH15 SLC12A...
# 1947  DLX3 INA LIX1 OLFM1 PCDH15 PHOX2A PTPRR SLCO6A...
# 1426    CTCFL DPEP3 MAGEA10 MAGEA11 MAGEA4 MAGEC1 STK31
# ...                                                 ...
# 1966                     HIF3A INA KIF1A STK31 TMEM132B
# 1308                          COL9A1 COL9A2 PRSS1 PRSS2
# 1778                                        BMP7 LIN28B
# 1967             BNIPL CCL28 PIGR SERPINA1 SLCO4C1 UPK2
# 1968                                         CLDN6 UPK2
#
# [92 rows x 7 columns]

# %% [markdown]
# ### ORA for biclusters prioritized by RSF

# %%
exprs_file = "../data/UKE_244.exprs.tsv.gz" 
annot = pd.read_csv("../data/UKE.sample_annotation_v4_181samples.tsv",sep ="\t",index_col=0)

out_dir = "unpast_results/" 
basename = 'UKE_244'

exprs = pd.read_csv(exprs_file,sep="\t",index_col=0)
print(exprs.shape)
exprs.head(3)
# Out:
# (23758, 244)
#                     T0063     T0096     T0103     T0249     T0294     T0305  \
# ENSG00000012124  9.027778  7.575057  7.261707  9.946216  9.903127  7.871454
# ENSG00000260083  3.660087  3.141124  2.923667  3.939617  3.530985  3.802634
# ENSG00000176887  9.648030  4.776085  6.083604  7.272087  2.432884  6.795860
#
#                    T0315     T0342     T0430     T0644  ...     T6985  \
# ENSG00000012124  9.29040  9.726680  9.152180  9.247163  ...  5.218529
# ENSG00000260083  3.37083  3.531991  3.817024  4.534004  ...  2.437952
# ENSG00000176887  0.00000  6.245121  8.322694  3.000023  ...  8.648666
#
#                     T6987     T6990     T6991     T6993     T6995     T6999  \
# ENSG00000012124  5.232677  7.880272  4.017847  7.706173  4.629797  5.397713
# ENSG00000260083  2.449817  3.532084  3.738694  2.859947  4.268662  3.101250
# ENSG00000176887  6.330015  8.254377  3.632195  3.616804  4.629797  5.111689
#
#                     T7001     T7002     T7003
# ENSG00000012124  8.116292  9.344000  9.764757
# ENSG00000260083  1.871275  2.633388  1.929429
# ENSG00000176887  4.083328  6.367058  5.607441
#
# [3 rows x 244 columns]

# %%
# functions to rename genes 
gene_info = pd.read_csv("../data/gene_id_mapping.tsv", sep ="\t",index_col=0)
gene_info.set_index("ensembl_gene_id",inplace=True)
ens2hgnc = gene_info["hgnc_symbol"].dropna().to_dict() 
def rename_gene(g,mapper=ens2hgnc, not_mapped = "", keep_not_mapped = False):
    if g in ens2hgnc.keys():
        return mapper[g]
    else:
        if keep_not_mapped:
            return g
        else:
            return not_mapped
        
def rename_genes_in_biclusters(biclusters, rename_gene_func = rename_gene):
    renamed_biclusters = biclusters.copy()
    renamed_biclusters["genes"] = renamed_biclusters["genes"].apply(lambda genes: set([rename_gene_func(x, keep_not_mapped=True) for x in genes]))
    renamed_biclusters["genes_up"] = renamed_biclusters["genes_up"].apply(lambda genes: set([rename_gene_func(x, keep_not_mapped=True) for x in genes]))
    renamed_biclusters["genes_down"] = renamed_biclusters["genes_down"].apply(lambda genes: set([rename_gene_func(x, keep_not_mapped=True) for x in genes]))
    return renamed_biclusters

def rename_genes_in_exprs(data, rename_gene_func = rename_gene):
    renamed_data = data.copy()
    renamed_data.index = [rename_gene_func(x, keep_not_mapped=True) for x in renamed_data.index ]
    # drop duplicates 
    renamed_data = renamed_data[~renamed_data.index.duplicated()]
    return renamed_data

# %%
analysis_seed =  42
n_runs = 10
seeds = []
random.seed(analysis_seed)
for i in range(n_runs):
    seeds.append(random.randint(0,1000000))
print("generate ",n_runs," seeds",seeds)
biclusters = []
# Out:
# generate  10  seeds [670487, 116739, 26225, 777572, 288389, 256787, 234053, 146316, 772246, 107473]

# %%
suffix = ".bin=kmeans,pval=0.01,clust=WGCNA,direction=DOWN-UP,ds=3,dch=0.995,max_power=10,precluster=True.biclusters.tsv"
biclusters = []
for seed in seeds:
    # find and save biclusters
    fname = out_dir+basename+".seed="+str(seed)+suffix
    if not os.path.exists(fname):
        results = unpast(exprs_file,
                      basename,
                      out_dir=out_dir,
                      #load=True,
                      seed = seed,
                      verbose = False
                     )
    else:
        results = read_bic_table(fname)
    # make bicluster ids unique: 'seed=<seed>_<bicluster id>'
    results.index = ["seed="+str(seed)+"_"+str(x) for x in results.index.values ]
    biclusters.append(results)
    print("seed=%s\tn_biclusters: %s"%(seed, results.shape[0]))
# Out:
# seed=670487	n_biclusters: 205
# seed=116739	n_biclusters: 228
# seed=26225	n_biclusters: 208
# seed=777572	n_biclusters: 201
# seed=288389	n_biclusters: 194
# seed=256787	n_biclusters: 213
# seed=234053	n_biclusters: 215
# seed=146316	n_biclusters: 200
# seed=772246	n_biclusters: 197
# seed=107473	n_biclusters: 227

# %%
from unpast.utils.consensus import make_consensus_biclusters
# filter and z-score transform input matrix, limit z-scores to [-3,3]
exprs_z = prepare_input_matrix(exprs, min_n_samples=5,ceiling=3)
uke_bics =  make_consensus_biclusters(biclusters,
                                      exprs_z, 
                                                 seed = analysis_seed,
                                                 verbose = True,
                                                 frac_runs=0.2,
                                                 plot = False
                                                )


uke_bics.head(5)
# Out:
# 218 s for similarity matrix
# 	Running Louvain ...
# 		modularity: newman
# 	curve type: increasing
# 	Louvain runtime: modules detected in 5.06 s.
# 	modules: 234, not clustered features 49
# 		similarity cutoff: 0.43 modularity: 0.994
# keep genes included in at least 2 merged biclusters
# all consensus biclusters: 283
# detected 2+ times:234
# 8 s for making consensus biclusters from consensus gene sets
#         SNR  n_genes  n_samples  \
# 0  3.348530        2        111
# 1  2.673952        2         75
# 2  2.454886        2         57
# 3  2.268912        2         97
# 4  2.184297        4         14
#
#                                                genes  \
# 0                 {ENSG00000204792, ENSG00000236209}
# 1                 {ENSG00000241945, ENSG00000160221}
# 2                 {ENSG00000187010, ENSG00000261349}
# 3                 {ENSG00000152977, ENSG00000174963}
# 4  {ENSG00000233515, ENSG00000265646, ENSG0000023...
#
#                                              samples  \
# 0  {T6732, T6656, T2497, T7003, T5741, T6787, T66...
# 1  {T6897, T6898, T6679, T2434, T7002, T6068, T67...
# 2  {T6159, T6732, T6656, T1702, T6991, T6706, T69...
# 3  {T6732, T6656, T2434, T0315, T5741, T6787, T63...
# 4  {T6789, T1702, T2434, T6726, T6068, T0430, T67...
#
#                                             genes_up  \
# 0                                                 {}
# 1                 {ENSG00000241945, ENSG00000160221}
# 2                                                 {}
# 3                 {ENSG00000152977, ENSG00000174963}
# 4  {ENSG00000233515, ENSG00000265646, ENSG0000023...
#
#                            genes_down               gene_indexes  \
# 0  {ENSG00000204792, ENSG00000236209}             {19402, 22351}
# 1                                  {}              {22705, 3483}
# 2  {ENSG00000187010, ENSG00000261349}              {9330, 21459}
# 3                                  {}              {22442, 8551}
# 4                                  {}  {17842, 19121, 1698, 469}
#
#                                       sample_indexes direction  \
# 0  {1, 2, 5, 7, 9, 10, 14, 21, 22, 23, 24, 25, 29...      DOWN
# 1  {130, 131, 133, 134, 139, 14, 15, 16, 17, 18, ...        UP
# 2  {128, 1, 2, 3, 133, 134, 135, 8, 136, 11, 12, ...      DOWN
# 3  {3, 6, 10, 28, 37, 39, 40, 41, 42, 43, 44, 45,...        UP
# 4  {161, 2, 98, 130, 131, 8, 44, 109, 176, 213, 1...        UP
#
#    detected_n_times                                                ids
# 0                10  {seed=26225_0, seed=116739_1, seed=146316_0, s...
# 1                10  {seed=107473_3, seed=146316_4, seed=288389_3, ...
# 2                 7  {seed=256787_3, seed=772246_4, seed=777572_5, ...
# 3                10  {seed=116739_99, seed=107473_7, seed=288389_7,...
# 4                10  {seed=234053_2, seed=670487_11, seed=107473_2,...

# %%
outfile = out_dir+basename+".consensus_seed="+str(analysis_seed)+".n_runs=10.biclusters.tsv"
#write_bic_table(uke_bics,outfile)
outfile
# Out:
# 'unpast_results/UKE_244.consensus_seed=42.n_runs=10.biclusters.tsv'

# %%
outfile = out_dir+basename+".consensus_seed="+str(analysis_seed)+".n_runs=10.biclusters.tsv"
exprs_z = prepare_input_matrix(exprs, min_n_samples=5,ceiling=3)
uke_bics = read_bic_table(outfile)
uke_bics["genes_renamed"] = uke_bics["genes"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
uke_bics["genes_up_renamed"] = uke_bics["genes_up"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
uke_bics["genes_down_renamed"] = uke_bics["genes_down"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
uke_bics.shape[0]
# Out:
# 234

# %%
"""from openpyxl import load_workbook

xls_flie = 'tables/S2_UKE_Biclusters.xlsx'

cols = ['SNR', 'n_genes', 'n_samples', 'genes', 'samples', 'genes_up',
       'genes_down', 'direction', 'genes_renamed', 'genes_up_renamed',
       'genes_down_renamed']
set_cols = [ 'genes', 'samples', 'genes_up', 'genes_down', 
            'genes_renamed', 'genes_up_renamed', 'genes_down_renamed']
df = uke_bics.loc[:,cols].copy()
for col in set_cols:
    df[col] = df[col].apply(lambda x: " ".join(sorted(x)))
with pd.ExcelWriter(xls_flie, engine='openpyxl') as writer:
    if not os.path.exists(xls_flie):
        pd.DataFrame().to_excel(writer, engine='openpyxl', sheet_name= "description")
    df.to_excel(writer, engine='openpyxl', sheet_name= "S2")"""

# %%
# filter out poor biomarker candidates
uke_bics["genes_renamed"] = uke_bics["genes"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
uke_bics = uke_bics.loc[uke_bics['SNR']>1.5,:]
uke_bics = uke_bics.loc[uke_bics['n_genes']>=2,:]
uke_bics.shape[0]
# Out:
# 177

# %%
# subset biclusters to 181 samples used in survival analysis
uke_bics["samples"] =  uke_bics["samples"].apply(lambda x : x.intersection(set(annot.index.values)))
uke_bics["n_samples"] = uke_bics["samples"].apply(lambda x :len(x) )
flip_bics = uke_bics.loc[uke_bics["n_samples"]>annot.shape[0]/2,:].index.values
uke_bics.loc[flip_bics,"samples"] =  uke_bics.loc[flip_bics,"samples"].apply(lambda x : set(annot.index.values).difference(x))
uke_bics.loc[flip_bics,"n_samples"] =  uke_bics.loc[flip_bics,"samples"].apply(lambda x :len(x) )
d = {"UP":"DOWN","DOWN":"UP","BOTH":"BOTH"}
uke_bics.loc[flip_bics,"direction"] = uke_bics.loc[flip_bics,"direction"].apply(lambda x: d[x])
genes_up  = uke_bics.loc[flip_bics,"genes_up"].copy()
genes_down  = uke_bics.loc[flip_bics,"genes_down"].copy()
uke_bics.loc[flip_bics,"genes_up"] = genes_down
uke_bics.loc[flip_bics,"genes_down"] = genes_up 
uke_bics.loc[flip_bics,:]
# Out:
#           SNR  n_genes  n_samples  \
# id
# 16   1.977286        3         90
# 107  1.607980        4         88
# 139  1.563189        3         88
# 143  1.558024        6         87
#
#                                                  genes  \
# id
# 16   {ENSG00000218048, ENSG00000146166, ENSG0000021...
# 107  {ENSG00000016082, ENSG00000159556, ENSG0000013...
# 139  {ENSG00000138435, ENSG00000265579, ENSG0000016...
# 143  {ENSG00000269345, ENSG00000213973, ENSG0000026...
#
#                                                samples  \
# id
# 16   {T6671, T6756, T4817, T6955, T6700, T3318, T61...
# 107  {T6898, T6671, T4817, T6960, T6795, T6700, T69...
# 139  {T6898, T6756, T4817, T6955, T6960, T6737, T33...
# 143  {T6898, T6756, T6681, T6732, T6955, T6960, T67...
#
#                                               genes_up  \
# id
# 16                                                  {}
# 107                                                 {}
# 139                                                 {}
# 143  {ENSG00000269345, ENSG00000213973, ENSG0000026...
#
#                                             genes_down  \
# id
# 16   {ENSG00000218048, ENSG00000146166, ENSG0000021...
# 107  {ENSG00000016082, ENSG00000159556, ENSG0000013...
# 139  {ENSG00000138435, ENSG00000265579, ENSG0000016...
# 143                                                 {}
#
#                                gene_indexes  \
# id
# 16                      {5480, 14974, 6671}
# 107            {17113, 11842, 14772, 23567}
# 139                    {7981, 22813, 20646}
# 143  {9331, 10355, 19573, 7379, 2202, 7582}
#
#                                         sample_indexes direction  \
# id
# 16   {4, 6, 7, 8, 9, 10, 24, 26, 27, 29, 30, 31, 33...      DOWN
# 107  {3, 5, 7, 10, 11, 12, 13, 15, 24, 25, 26, 31, ...      DOWN
# 139  {0, 1, 2, 5, 7, 10, 15, 16, 19, 23, 25, 26, 28...      DOWN
# 143  {0, 2, 3, 6, 7, 8, 9, 10, 11, 12, 13, 14, 22, ...        UP
#
#      detected_n_times                                                ids  \
# id
# 16                 10  seed=107473_58 seed=116739_22 seed=146316_21 s...
# 107                10  seed=107473_138 seed=116739_126 seed=146316_85...
# 139                 8  seed=116739_138 seed=146316_151 seed=234053_12...
# 143                10  seed=107473_108 seed=116739_117 seed=146316_12...
#
#                                          genes_renamed  \
# id
# 16            {ENSG00000218048, ENSG00000218274, LGSN}
# 107                       {ISL1, ISL1-DT, ISL2, BARX1}
# 139                   {NETO1, CHRNA1, ENSG00000265579}
# 143  {ZNF728, BNIP3P30, BNIP3P28, ZNF99, VN1R85P, Z...
#
#                              genes_up_renamed  \
# id
# 16   {ENSG00000218048, ENSG00000218274, LGSN}
# 107              {ISL1, ISL1-DT, ISL2, BARX1}
# 139          {NETO1, CHRNA1, ENSG00000265579}
# 143                                        {}
#
#                                     genes_down_renamed
# id
# 16                                                  {}
# 107                                                 {}
# 139                                                 {}
# 143  {ZNF728, BNIP3P30, BNIP3P28, ZNF99, VN1R85P, Z...

# %% [markdown]
# ### Biclusters that can be validated in DASL

# %%
exprs_dasl = pd.read_csv("../data/DASL_377.exprs.tsv.gz",sep="\t",index_col=0)
exprs_dasl_z = prepare_input_matrix(exprs_dasl, min_n_samples=5,ceiling=3)
annot_dasl = pd.read_csv("../data/DASL.annotation_Kommoss.tsv.gz",sep ="\t",index_col=0)
print(exprs_dasl.shape)
exprs_dasl.head()
# Out:
# (19369, 377)
#                  X5800701006_B  X5800701006_C  X5800701006_D  X5800701006_E  \
# ENSG00000000003       9.909752       9.525017       9.389951       8.906697
# ENSG00000000005       5.796944       6.934209       6.029834       8.056683
# ENSG00000000419      11.339043      10.833057      11.496018      10.982706
# ENSG00000000457      10.629205      10.656287      11.025044      10.551419
# ENSG00000000460       9.995577       9.537950      10.663028       9.311639
#
#                  X5800701006_F  X5800701006_G  X5800701006_I  X5800701006_J  \
# ENSG00000000003       8.872511       9.435739       8.682605       8.263090
# ENSG00000000005       5.848083      10.293842      12.859131       5.729206
# ENSG00000000419      10.874035      11.155626      10.796318      11.005716
# ENSG00000000457      10.214125      10.132513      10.144994      10.633829
# ENSG00000000460       9.448363       9.762461       9.389263       8.571140
#
#                  X5800701006_K  X5800701006_L  ...  X6828280034_C  \
# ENSG00000000003      10.024749       7.500624  ...       8.821913
# ENSG00000000005       7.629308       5.864953  ...       7.105938
# ENSG00000000419      10.904402      10.653652  ...      11.057507
# ENSG00000000457      10.274398      10.735102  ...       9.841599
# ENSG00000000460       8.477068       7.561917  ...       9.209328
#
#                  X6828280034_F  X6828280034_H  X6828280034_I  X6828280034_J  \
# ENSG00000000003       9.981615       8.306561       9.164281       7.774171
# ENSG00000000005       6.985320       7.148474       7.285059       7.248570
# ENSG00000000419      10.987369      10.853487      10.991282      10.367209
# ENSG00000000457      10.999188      10.837943      10.499959       9.962178
# ENSG00000000460       9.557169       8.693149       8.978283       9.926642
#
#                  X6828280034_K  X6828280034_L  X6828301015_B  X6828301015_C  \
# ENSG00000000003       8.969784      10.373839       9.417089       9.138731
# ENSG00000000005       8.255288       9.003298       7.328400       7.132316
# ENSG00000000419      10.474167      11.272424      10.179407      11.523776
# ENSG00000000457      11.014410      10.693222      10.562305      10.219488
# ENSG00000000460       8.063229       9.455161       9.372415       8.529636
#
#                  X6828301015_D
# ENSG00000000003       8.597400
# ENSG00000000005       8.051942
# ENSG00000000419      11.308989
# ENSG00000000457      10.717282
# ENSG00000000460       9.913470
#
# [5 rows x 377 columns]

# %%
from aux import make_similar_biclusters

dasl_bics, gene_sets_stat = make_similar_biclusters(uke_bics, exprs_dasl_z,seed=analysis_seed)

dasl_bics = dasl_bics.loc[dasl_bics["SNR"]>1.5,:]
#dasl_bics = dasl_bics.loc[dasl_bics["SNR"]>1,:]
dasl_bics = dasl_bics.loc[dasl_bics["n_genes"]>1,:]
sele_bics_ids = dasl_bics.index.values
print(len(sele_bics_ids))
sele_bics_ids
# Out:
# 23
# array([ 10,  22,  27,  31,  34,  41,  59,  60,  62,  70,  72,  83,  84,
#         85,  90,  95, 103, 109, 117, 130, 144, 155, 168])

# %%
s  = "OS" # PFS
covariates = ["FIGO_IIIC","FIGO_IV","OP_1","OP_2","age"]
surv_cols = [s+"_event",s+"_time"]

# %% [markdown]
# # Random survival forest to selects predictive biomarker candidates

# %%
from sklearn import set_config
set_config(display="text")

from rsf import run_RSF_and_calc_feature_importance 
n_permutations = 1000

# Define parameter grid
param_grid = {
        'n_estimators': [10,15,20,25,30,35,40,45,50],
        'max_features': [None,'sqrt',10],
        'max_depth' : [2,3,4,5],
}

# %%
permut_result_beva, gs_beva = run_RSF_and_calc_feature_importance(uke_bics.loc[sele_bics_ids,:], annot,  #test
                                                                  dasl_bics.loc[sele_bics_ids,:], annot_dasl,# training
                                                                  treatment_col = "bevacizumab",
                                                                  treatment_value =1,
                                                                  covariates = covariates,
                                                                  surv_cols = [s+"_event",s+"_time"],
                                                                  analysis_seed = analysis_seed,
                                                                  n_permutations = n_permutations,
                                                                  param_grid = param_grid)

permut_result_beva.columns = ["beva_"+s+"."+x for x 
                              in permut_result_beva.columns]
# Out:
# 5 biclusters not passed min_n_samples=10 filter removed: {'bic27', 'bic34', 'bic22', 'bic10', 'bic31'}
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best parameters: {'max_depth': 2, 'max_features': 10, 'n_estimators': 15}
# RSF scores: Test: 0.60 (train: 0.75)

# %%
# GS results visualization
df = pd.DataFrame.from_records(gs_beva.cv_results_['params'])
df["mean_score"] = gs_beva.cv_results_['mean_test_score']
df["max_features"]= df["max_features"].fillna("NA")
sns.boxplot(data = df, y="mean_score", x= "max_depth", hue ="max_features")
plt.show()

# %%
sns.boxplot(data = df, y="mean_score", x= "n_estimators", hue ="max_features")
plt.show()

# %%
permut_result_st, gs_st = run_RSF_and_calc_feature_importance(uke_bics.loc[sele_bics_ids,:], annot,  #test
                                                              dasl_bics.loc[sele_bics_ids,:], annot_dasl,# training
                                                              treatment_col = "bevacizumab",
                                                              treatment_value =0,
                                                                covariates = covariates,
                                                                surv_cols = [s+"_event",s+"_time"],
                                                                analysis_seed = analysis_seed,
                                                                n_permutations = n_permutations,
                                                                param_grid = param_grid
)
permut_result_st.columns = ["st_"+s+"."+x for x in permut_result_st.columns]
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best parameters: {'max_depth': 2, 'max_features': None, 'n_estimators': 20}
# RSF scores: Test: 0.60 (train: 0.69)

# %%
# GS results visualization
df = pd.DataFrame.from_records(gs_st.cv_results_['params'])
df["mean_score"] = gs_st.cv_results_['mean_test_score']
df["max_features"]= df["max_features"].fillna("NA")
sns.boxplot(data = df, y="mean_score", x= "max_depth", hue ="max_features")
plt.show()

# %%
sns.boxplot(data = df, y="mean_score", x= "n_estimators", hue ="max_features")
plt.show()

# %%
shared_variables = [x for x in permut_result_beva.index.values if x in permut_result_st.index.values]
df = pd.concat([permut_result_beva.loc[shared_variables,:],
           permut_result_st.loc[shared_variables,:]],
          axis=1)
df["diff"] = df["beva_"+s+".importances_mean"] - df["st_"+s+".importances_mean"]
d = df.sort_values(by = "beva_"+s+".importances_mean",ascending = False).loc[:,["beva_"+s+".importances_mean","st_"+s+".importances_mean","diff"]]
d = d.loc[d["beva_"+s+".importances_mean"]>0,:]

sele_features_beva =  d.index.values

sele_bics_beva = [int(x.replace("bic","")) for x in sele_features_beva if not x in covariates]
print(sele_features_beva)
print(sele_bics_beva)                 
d.loc[sele_features_beva,:]
# Out:
# ['age' 'bic70' 'bic84' 'bic130' 'bic90' 'OP_2' 'bic109']
# [70, 84, 130, 90, 109]
#         beva_OS.importances_mean  st_OS.importances_mean      diff
# age                     0.040348                0.009414  0.030934
# bic70                   0.020886               -0.001172  0.022058
# bic84                   0.013131                0.000000  0.013131
# bic130                  0.010104                0.000000  0.010104
# bic90                   0.005135                0.000000  0.005135
# OP_2                    0.001002                0.045254 -0.044252
# bic109                  0.000989                0.000475  0.000514

# %%
shared_variables = [x for x in permut_result_beva.index.values if x in permut_result_st.index.values]
df = pd.concat([permut_result_beva.loc[shared_variables,:],
           permut_result_st.loc[shared_variables,:]],
          axis=1)
df["diff"] = df["st_"+s+".importances_mean"] - df["beva_"+s+".importances_mean"]
d = df.sort_values(by = "st_"+s+".importances_mean",ascending = False).loc[:,["beva_"+s+".importances_mean","st_"+s+".importances_mean","diff"]]
#d = d.loc[d["st_"+s+".importances_mean"]>0,:]
#d = d.loc[d["diff"]>0,:]
sele_features_st =  d.index.values
sele_bics_st = [int(x.replace("bic","")) for x in sele_features_st if not x in covariates]
print(sele_features_st)
print(sele_bics_st)                 
#d
# Out:
# ['OP_2' 'FIGO_IV' 'OP_1' 'age' 'bic60' 'bic95' 'bic109' 'bic168' 'bic85'
#  'bic155' 'bic103' 'bic144' 'bic72' 'bic83' 'bic59' 'FIGO_IIIC' 'bic90'
#  'bic130' 'bic84' 'bic70' 'bic41' 'bic117' 'bic62']
# [60, 95, 109, 168, 85, 155, 103, 144, 72, 83, 59, 90, 130, 84, 70, 41, 117, 62]

# %%
shared_variables = [x for x in permut_result_beva.index.values if x in permut_result_st.index.values]
df = pd.concat([permut_result_beva.loc[shared_variables,:],
           permut_result_st.loc[shared_variables,:]],
          axis=1)
df.loc[list(set(sele_features_beva)|set(sele_features_st)),:].sort_values(by="beva_"+s+".importances_mean",ascending = False)
df.loc[list(set(sele_features_beva)|set(sele_features_st)),["beva_"+s+".importances_mean", "st_"+s+".importances_mean"]].sort_values(by="beva_"+s+".importances_mean",ascending = False)
# Out:
#            beva_OS.importances_mean  st_OS.importances_mean
# age                        0.040348                0.009414
# bic70                      0.020886               -0.001172
# bic84                      0.013131                0.000000
# bic130                     0.010104                0.000000
# bic90                      0.005135                0.000000
# OP_2                       0.001002                0.045254
# bic109                     0.000989                0.000475
# bic59                      0.000000                0.000000
# bic62                      0.000000               -0.006273
# bic41                      0.000000               -0.001187
# FIGO_IIIC                  0.000000                0.000000
# bic103                     0.000000                0.000000
# OP_1                       0.000000                0.009455
# bic95                      0.000000                0.002608
# bic72                      0.000000                0.000000
# bic83                      0.000000                0.000000
# FIGO_IV                    0.000000                0.013538
# bic60                      0.000000                0.008619
# bic155                    -0.000020                0.000000
# bic85                     -0.000278                0.000000
# bic117                    -0.001479               -0.003148
# bic168                    -0.002266                0.000000
# bic144                    -0.003740                0.000000

# %% [markdown]
# # Predictive candidates

# %%
sele_bics_ids = sele_bics_beva
sele_bics_ids
# Out:
# [70, 84, 130, 90, 109]

# %%
#s = "OS"
s, sele_bics_ids# = [84, 130, 72,95,85]
# Out:
# ('OS', [70, 84, 130, 90, 109])

# %%
from bic_survival_tests import test_predictive_biclusters
uke_os = test_predictive_biclusters(uke_bics.loc[sele_bics_ids,:],
                                annot,
                                treatment_col= "bevacizumab",
                                time_col = s+"_time",
                                event_col = s+"_event",
                                covariates = covariates, min_n_samples=10)
# Out:
# Biclusters tested: 5

# %%
fdr = 1 # 0.05
passed_uke = set(uke_os.loc[uke_os["min_adj_pval"]<fdr,:].index.values)
print(len(passed_uke))
uke_os.loc[passed_uke,:].sort_values(by=["min_adj_pval","min_pval"])#.head(30)
# Out:
# 5
#       bg.pval     bg.HR                                    bg.CI95 bg.beva  \
# 90   0.002677  0.371431   (0.19458866811754102, 0.708988594645302)      33
# 84   0.003082  0.408457  (0.22574659321570492, 0.7390472470560943)      39
# 130  0.004821  0.407069  (0.21789966238664504, 0.7604667506921334)      35
# 70   0.218892  0.738448   (0.4554113029414694, 1.1973923105653326)      44
# 109  0.029728  0.548936   (0.31963595720650123, 0.942731410388946)      39
#
#     bg.st bg.covar_excl  bic.pval    bic.HR  \
# 90     74            []  0.410723    0.7827
# 84     60            []  0.968537  1.012052
# 130    78            []   0.17221  0.635371
# 70     64            []   0.00525  0.255455
# 109    79            []  0.507484  0.782094
#
#                                       bic.CI95 bic.beva bic.st bic.covar_excl  \
# 90   (0.43659289303253185, 1.4031803219057117)       34     40             []
# 84     (0.5580419556101323, 1.835434692091807)       28     54             []
# 130   (0.33130581497885814, 1.218501722853906)       32     36             []
# 70   (0.09798134044989751, 0.6660193861119814)       23     50             []
# 109    (0.378091022304504, 1.6177871712330978)       28     35             []
#
#     direction predictive bevacizumab_eff bic.pval_BH bg.pval_BH  min_adj_pval  \
# 90         UP        low             pos    0.634355   0.007704      0.007704
# 84       DOWN       high             pos    0.968537   0.007704      0.007704
# 130        UP        low             pos    0.430525   0.008036      0.008036
# 70       DOWN        low             pos    0.026252   0.218892      0.026252
# 109        UP        low             pos    0.634355    0.03716      0.037160
#
#      min_pval
# 90   0.002677
# 84   0.003082
# 130  0.004821
# 70   0.005250
# 109  0.029728

# %% [markdown]
# ### Predictive biclusters
# * model with interaction term

# %%
from bic_survival_tests import test_predictive_with_interaction

# %%
surv_data = annot.loc[:,covariates+["bevacizumab",s+"_time",s+"_event"]]
#formula = "age + FIGO_IIIC + FIGO_IV + OP_1 + OP_2 + bevacizumab * bic"

df = test_predictive_with_interaction(uke_bics.loc[sele_bics_ids,:],
                                     surv_data,
                                     covariates=covariates,
                                     treatment_col = "bevacizumab",
                                     duration_col=s+"_time",
                                     event_col= s+"_event",
                                     min_n_samples=10,
                                    )

print(df.shape[0])
df.loc[df["bevacizumab:bic_pval_BH"]<1]#.sort_values(by = ["bevacizumab:bic_pval_BH","bevacizumab:bic_pval"])
# Out:
# formula: FIGO_IIIC + FIGO_IV + OP_1 + OP_2 + age + bevacizumab * bic
# 5
#     bevacizumab_bic bevacizumab_bg standard_bic standard_bg  \
# 109              28             39           35          79
# 130              32             35           36          78
# 70               23             44           50          64
# 84               28             39           54          60
# 90               34             33           40          74
#
#     bevacizumab:bic_pval bevacizumab:bic_HR  \
# 109             0.533283           1.305883
# 130              0.28696           1.590459
# 70              0.090687           0.426239
# 84              0.069179           2.095788
# 90              0.183871           1.753155
#
#                          bevacizumab:bic_CI95 bevacizumab_pval bevacizumab_HR  \
# 109    (3.023702244656595, 0.563987879640907)         0.035232       0.564534
# 130   (3.736437188422762, 0.6769981683293766)          0.02241       0.498892
# 70   (1.1447391819397987, 0.1587086935501607)          0.25569       0.758768
# 84     (4.65512046354022, 0.9435475974347897)         0.007067       0.456542
# 90   (4.0125190401907584, 0.7659906215311988)          0.01046       0.446619
#
#                               bevacizumab_CI95  bic_pval    bic_HR  \
# 109  (0.9612050456462706, 0.33156115449504897)  0.162024  0.704984
# 130   (0.9062100877132652, 0.2746527342243978)  0.241324  0.741784
# 70   (1.2213585163676157, 0.47138417898120805)  0.522168  0.861652
# 84    (0.8076980466074382, 0.2580556432520973)  0.681329  1.100887
# 90   (0.8277944736884252, 0.24096412752149396)  0.857916   1.04299
#
#                                       bic_CI95 bevacizumab:bic_pval_BH  \
# 109  (1.1507559307929232, 0.43189261688929065)                0.533283
# 130   (1.222571407450595, 0.45007014243340937)                  0.3587
# 70     (1.3594783823560797, 0.546123820708642)                0.226717
# 84    (1.7417003483229294, 0.6958441149051381)                0.226717
# 90     (1.653507820072745, 0.6578906149136144)                0.306452
#
#     bevacizumab_pval_BH bic_pval_BH
# 109             0.04404     0.60331
# 130            0.037349     0.60331
# 70              0.25569    0.851661
# 84             0.026149    0.851661
# 90             0.026149    0.857916

# %%
v = "bevacizumab:bic_"
df.loc[:,[v+"pval",v+"pval_BH",v+"HR",v+"CI95"]]
# Out:
#     bevacizumab:bic_pval bevacizumab:bic_pval_BH bevacizumab:bic_HR  \
# 109             0.533283                0.533283           1.305883
# 130              0.28696                  0.3587           1.590459
# 70              0.090687                0.226717           0.426239
# 84              0.069179                0.226717           2.095788
# 90              0.183871                0.306452           1.753155
#
#                          bevacizumab:bic_CI95
# 109    (3.023702244656595, 0.563987879640907)
# 130   (3.736437188422762, 0.6769981683293766)
# 70   (1.1447391819397987, 0.1587086935501607)
# 84     (4.65512046354022, 0.9435475974347897)
# 90   (4.0125190401907584, 0.7659906215311988)

# %%
# prognostic
v = "bic_"
df.loc[:,[v+"pval",v+"pval_BH",v+"HR",v+"CI95"]]
# Out:
#      bic_pval bic_pval_BH    bic_HR                                   bic_CI95
# 109  0.162024     0.60331  0.704984  (1.1507559307929232, 0.43189261688929065)
# 130  0.241324     0.60331  0.741784   (1.222571407450595, 0.45007014243340937)
# 70   0.522168    0.851661  0.861652    (1.3594783823560797, 0.546123820708642)
# 84   0.681329    0.851661  1.100887   (1.7417003483229294, 0.6958441149051381)
# 90   0.857916    0.857916   1.04299    (1.653507820072745, 0.6578906149136144)

# %% [markdown]
# # validation in DASL

# %%
print(len(passed_uke))
# Out:
# 5

# %%
dasl_os = test_predictive_biclusters(dasl_bics.loc[sele_bics_ids,:],
                                 annot_dasl, 
                                 treatment_col= "bevacizumab",
                                 time_col = s+"_time",
                                 event_col = s+"_event",
                                 covariates = covariates)

passed_dasl = dasl_os.loc[dasl_os["min_adj_pval"]<fdr,:].index.values
print(len(passed_dasl))
dasl_os.loc[passed_dasl,:]
# Out:
# Biclusters tested: 5
# 5
#       bg.pval     bg.HR                                    bg.CI95 bg.beva  \
# 84    0.00065  0.507434  (0.34358167164567155, 0.7494261787624645)     101
# 130  0.016754  0.680032   (0.49580485061963775, 0.932714111809023)     174
# 109  0.056494  0.723036   (0.5181118931198211, 1.0090112411728958)     158
# 70   0.059382  0.697446   (0.4795440113652737, 1.0143612044004409)     129
# 90   0.128555  0.719959   (0.4712948809260568, 1.0998240133441384)     104
#
#     bg.st bg.covar_excl  bic.pval    bic.HR  \
# 84     94            []  0.870703  1.036488
# 130   151            []  0.516382   1.28076
# 109   137            []  0.350371  0.758663
# 70    111            []  0.395345  0.824636
# 90     92            []  0.102513  0.720491
#
#                                       bic.CI95 bic.beva bic.st bic.covar_excl  \
# 84     (0.6731995827634121, 1.595823674480094)       97     85             []
# 130    (0.6065744876064966, 2.704276159732652)       24     28             []
# 109   (0.4249133259210897, 1.3545559139230452)       40     42             []
# 70    (0.5286505761478579, 1.2863405186414003)       69     68             []
# 90   (0.48610311785410787, 1.0678941329636042)       94     87             []
#
#     direction predictive bevacizumab_eff bic.pval_BH bg.pval_BH  min_adj_pval  \
# 84       DOWN       high             pos    0.870703   0.003251      0.003251
# 130        UP        low             pos    0.645478   0.041885      0.041885
# 109        UP        low             pos    0.645478   0.074227      0.074227
# 70         UP        low             pos    0.645478   0.074227      0.074227
# 90         UP       high             pos    0.512567   0.128555      0.128555
#
#      min_pval
# 84   0.000650
# 130  0.016754
# 109  0.056494
# 70   0.059382
# 90   0.102513

# %%
surv_data = annot_dasl.loc[:,covariates+["bevacizumab",s+"_time",s+"_event"]]

df = test_predictive_with_interaction(dasl_bics.loc[sele_bics_ids,:],
                                     surv_data,
                                     covariates=covariates,
                                     treatment_col = "bevacizumab",
                                     duration_col=s+"_time",
                                     event_col= s+"_event",
                                     min_n_samples=10,
                                    )

print(df.shape[0])
df.loc[df["bevacizumab:bic_pval"]<1,:]
# Out:
# formula: FIGO_IIIC + FIGO_IV + OP_1 + OP_2 + age + bevacizumab * bic
# 5
#     bevacizumab_bic bevacizumab_bg standard_bic standard_bg  \
# 84               97            101           85          94
# 130              24            174           28         151
# 109              40            158           42         137
# 90               94            104           87          92
# 70               69            129           68         111
#
#     bevacizumab:bic_pval bevacizumab:bic_HR  \
# 84              0.013626           2.061498
# 130             0.134611           1.765634
# 109              0.64217           1.165657
# 90              0.924283            1.02802
# 70              0.513614           1.211685
#
#                          bevacizumab:bic_CI95 bevacizumab_pval bevacizumab_HR  \
# 84   (3.6626561476239523, 1.1602987123755164)         0.000872       0.521548
# 130   (3.7182502945929206, 0.838422279062523)         0.018169       0.683782
# 109   (2.225188098007718, 0.6106257015251766)         0.038762       0.704447
# 90   (1.8176228097011748, 0.5814325652507583)          0.10461       0.706222
# 70   (2.1557462935852136, 0.6810547417196099)          0.03317       0.668198
#
#                               bevacizumab_CI95  bic_pval    bic_HR  \
# 84     (0.765142267308274, 0.3555061834814814)  0.092818  0.696451
# 130  (0.9373307237194068, 0.49881826597958895)  0.205042  1.389459
# 109   (0.9820678679895953, 0.5053066764936925)  0.391227  1.217259
# 90    (1.0749129620374676, 0.4639902443751798)  0.480276  1.156823
# 70   (0.9683237278701086, 0.46109497565196284)  0.837782  0.957765
#
#                                      bic_CI95 bevacizumab:bic_pval_BH  \
# 84   (1.0619485568462221, 0.4567493788511178)                0.068132
# 130  (2.3108044257349167, 0.8354651195415561)                0.336527
# 109  (1.9079397159991922, 0.7766070325364207)                0.802712
# 90   (1.7335656589552983, 0.7719572702790062)                0.924283
# 70   (1.4476797370578485, 0.6336445952479888)                0.802712
#
#     bevacizumab_pval_BH bic_pval_BH
# 84             0.004359    0.464091
# 130            0.045424    0.512604
# 109            0.048452    0.600345
# 90              0.10461    0.600345
# 70             0.048452    0.837782

# %%
uke_bics.loc[84,"genes"]
# Out:
# {'ENSG00000144407',
#  'ENSG00000205359',
#  'ENSG00000225882',
#  'ENSG00000249721',
#  'ENSG00000250682'}

# %%
v = "bevacizumab:bic_"
df.loc[:,[v+"pval",v+"pval_BH",v+"HR",v+"CI95"]]
# Out:
#     bevacizumab:bic_pval bevacizumab:bic_pval_BH bevacizumab:bic_HR  \
# 84              0.013626                0.068132           2.061498
# 130             0.134611                0.336527           1.765634
# 109              0.64217                0.802712           1.165657
# 90              0.924283                0.924283            1.02802
# 70              0.513614                0.802712           1.211685
#
#                          bevacizumab:bic_CI95
# 84   (3.6626561476239523, 1.1602987123755164)
# 130   (3.7182502945929206, 0.838422279062523)
# 109   (2.225188098007718, 0.6106257015251766)
# 90   (1.8176228097011748, 0.5814325652507583)
# 70   (2.1557462935852136, 0.6810547417196099)

# %%
v = "bic_"
df.loc[:,[v+"pval",v+"pval_BH",v+"HR",v+"CI95"]]
# Out:
#      bic_pval bic_pval_BH    bic_HR                                  bic_CI95
# 84   0.092818    0.464091  0.696451  (1.0619485568462221, 0.4567493788511178)
# 130  0.205042    0.512604  1.389459  (2.3108044257349167, 0.8354651195415561)
# 109  0.391227    0.600345  1.217259  (1.9079397159991922, 0.7766070325364207)
# 90   0.480276    0.600345  1.156823  (1.7335656589552983, 0.7719572702790062)
# 70   0.837782    0.837782  0.957765  (1.4476797370578485, 0.6336445952479888)

# %%
uke_os.loc[passed_dasl,["direction","predictive","bevacizumab_eff",
                        "bg.pval","bic.pval","bg.HR","bic.HR"]]
# Out:
#     direction predictive bevacizumab_eff   bg.pval  bic.pval     bg.HR  \
# 84       DOWN       high             pos  0.003082  0.968537  0.408457
# 130        UP        low             pos  0.004821   0.17221  0.407069
# 109        UP        low             pos  0.029728  0.507484  0.548936
# 70       DOWN        low             pos  0.218892   0.00525  0.738448
# 90         UP        low             pos  0.002677  0.410723  0.371431
#
#        bic.HR
# 84   1.012052
# 130  0.635371
# 109  0.782094
# 70   0.255455
# 90     0.7827

# %%
dasl_os.loc[passed_dasl,["direction","predictive","bevacizumab_eff",
                         "bg.pval","bic.pval","bg.HR","bic.HR"]]
# Out:
#     direction predictive bevacizumab_eff   bg.pval  bic.pval     bg.HR  \
# 84       DOWN       high             pos   0.00065  0.870703  0.507434
# 130        UP        low             pos  0.016754  0.516382  0.680032
# 109        UP        low             pos  0.056494  0.350371  0.723036
# 70         UP        low             pos  0.059382  0.395345  0.697446
# 90         UP       high             pos  0.128555  0.102513  0.719959
#
#        bic.HR
# 84   1.036488
# 130   1.28076
# 109  0.758663
# 70   0.824636
# 90   0.720491

# %%
reproduced_bic_ids = uke_os.loc[passed_dasl,["predictive","bevacizumab_eff"]] == dasl_os.loc[passed_dasl,["predictive","bevacizumab_eff"]]
reproduced_bic_ids =reproduced_bic_ids.apply(lambda row: np.all(row),axis=1)
reproduced_bic_ids = list(reproduced_bic_ids[reproduced_bic_ids].index)
reproduced_bic_ids
# Out:
# [84, 130, 109, 70]

# %% [markdown]
# ### KM-plots predictive
#
# Fig. 2

# %%
from bic_survival_plots import plot_KM_predictive
bic_id =  84
bic_samples = uke_bics.loc[bic_id,"samples"].intersection(set(annot.index.values))
plot_KM_predictive(bic_samples, annot, uke_os, bic_id,
                   uke_bics.loc[bic_id,"direction"],
                   surv_time = s+"_time",
                   surv_event= s+"_event",
                   cohort = "UKE",
                   xlabel = s+", months",
                   add_counts=True,
                   label_pos=(2,0.05),
                   figsize = (11,4),
                   e = "expression",
                   add_subplot=True
                  )
plt.savefig("../img/Fig2ab_bic84_UKE.pdf")
# Out:
# (0.5580419556101323, 1.835434692091807)
# bicluster p-val.=9.69e-01, adj.p-val.=9.69e-01, HR=1.01(0.56,1.84);
# (0.22574659321570492, 0.7390472470560943)
# background p-val.=3.08e-03, adj.p-val.=7.70e-03, HR=0.41(0.23,0.74);
# 84 82

# %%
bic_samples = dasl_bics.loc[bic_id,"samples"].intersection(set(annot_dasl.index.values))
d = dasl_bics.loc[bic_id,"direction"]
plot_KM_predictive(bic_samples, annot_dasl, dasl_os, bic_id, d,
                    surv_time = s+"_time", surv_event= s+"_event",
                       cohort = "DASL",
                   label_pos=(2,0.05),
                  figsize = (11,4),
                   e = "expression",
                  add_counts = True,
                   add_subplot=True
                  )
plt.savefig("../img/Fig2ab_bic84_DASL.pdf")
# Out:
# (0.6731995827634121, 1.595823674480094)
# bicluster p-val.=8.71e-01, adj.p-val.=8.71e-01, HR=1.04(0.67,1.60);
# (0.34358167164567155, 0.7494261787624645)
# background p-val.=6.50e-04, adj.p-val.=3.25e-03, HR=0.51(0.34,0.75);
# 84 182

# %% [markdown]
# ### Plot biclusters

# %%
color_dict = {"bevacizumab":{0:"lightgrey",1:"darkgreen"},
              "consensusOV":{
    "MES_consensus":"orange",
    "PRO_consensus":"lime",
    "IMR_consensus": "magenta",
    "DIF_consensus":"cyan"
    },
    "subtype":{"MES":"orange", "mesenchymal":"orange",
    "PRO":"lime", 'proliferative':'lime',
    "IMR": "magenta", 'immunoreactive':'magenta',
    "DIF":"cyan",'differentiated':"cyan",
    "MES_consensus":"orange",
    "PRO_consensus":"lime",
    "IMR_consensus": "magenta",
    "DIF_consensus":"cyan",
    },
    "Bentink":{
    'Angiogenic':'violet',
    'nonAngiogenic':'gold'},
}

subt_dir = "../data/OVcancer_subtypes/"
uke_subt = pd.read_csv(subt_dir+"UKE181_OVconsensus_subtypes.tsv",sep ="\t",index_col=0)
dasl_subt = pd.read_csv(subt_dir+"DASL_Kommoss_OVconsensus_subtypes.tsv",sep ="\t",index_col=0)

dasl_subt["subtype"]=dasl_subt["consensusOV"]
uke_subt["subtype"]=uke_subt["consensusOV"]

# %%
exprs_z_rn = rename_genes_in_exprs(exprs_z.copy())

# %%
reproduced_bic_ids  = [84]

# %%
from unpast.utils.figs import draw_heatmap2

i = reproduced_bic_ids  
b = rename_genes_in_biclusters(uke_bics.loc[i,:].copy())
fs = 14

fig = draw_heatmap2(exprs_z_rn.loc[:,annot.index], b,
                    annot=uke_subt.loc[:,["subtype","Bentink"]],
                    color_dict=color_dict,
              bicluster_colors="redblue",
              figsize = (5,4), 
              dendrogram_ratio=(0.1,0.1),
              colors_ratio=(0.04, 0.04/10*8),
              bic_prefix = "b. ",
              legend_n_cols=0,
              no_cbar=True,
              col_labels = False,
              row_labels = True,
              highlight_row_labels=["PTH2R","SLCO6A1",
              "ADIPOQ","CIDEA","CIDEC","PLIN1","CD300LG","FABP4","RERGL",
                                   "EMX2","EMX2OS","FAM181A","CTCFL"],
                no_row_colors = False,cluster_rows=False
             )
ax = fig[0].ax_heatmap
tmp = ax.set_xlabel("UKE, n=%s samples"%annot.shape[0], fontsize=fs)
plt.show()

# %%
cols = ["bic"+str(x) for x in reproduced_bic_ids]
df = pd.DataFrame(np.zeros((annot.shape[0],len(cols))),
             index=annot.index,
             columns=cols)
for bic_id in reproduced_bic_ids:
    df.loc[uke_bics.loc[bic_id,"samples"],"bic"+str(bic_id)]=1
df = df.applymap(lambda x: int(x))
df.to_csv("UKE_181.design.tsv",sep ="\t")

# %%
exprs_z_dasl = zscore(exprs_dasl.copy())
exprs_z_rn_dasl = rename_genes_in_exprs(exprs_z_dasl.copy())

# %%
i = reproduced_bic_ids
b = rename_genes_in_biclusters(dasl_bics.loc[i,:].copy())

fig = draw_heatmap2(exprs_z_rn_dasl.loc[:,annot_dasl.index], b,
                    annot=dasl_subt.loc[:,["subtype"]],
                    color_dict=color_dict,
                    bicluster_colors="redblue",
                    figsize = (5,3), 
                    dendrogram_ratio=(0.05,0.05),
                    colors_ratio=(0.05/5*3, 0.05),
                    bic_prefix = "b. ",
                    legend_n_cols=0,
                    no_cbar=True,
                    col_labels = False,
                    row_labels = True,
                    highlight_row_labels=["PTH2R","SLCO6A1",
                    "ADIPOQ","CIDEA","CIDEC","PLIN1","CD300LG", "FABP4","RERGL",
                                       "EMX2","EMX2OS","FAM181A"],
no_row_colors = False,cluster_rows=False
             )
ax = fig[0].ax_heatmap
tmp = ax.set_xlabel("DASL, n=%s samples"%annot_dasl.shape[0], fontsize=fs)
plt.show()

# %%
cols = ["bic"+str(x) for x in reproduced_bic_ids]
df = pd.DataFrame(np.zeros((exprs_dasl.shape[1],len(cols))),
             index=exprs_dasl.columns,
             columns=cols)
for bic_id in reproduced_bic_ids:
    df.loc[dasl_bics.loc[bic_id,"samples"],"bic"+str(bic_id)]=1
df = df.applymap(lambda x: int(x))
df.to_csv("DASL_377.design.tsv",sep ="\t")

# %% [markdown]
# # DE analysis
#
# (reads limma's output tables; run notebook with DE analysis before running this tab)

# %%
lfc = 1
p = 0.05#1e-5 #0.01
de_shared = {}
query_gset_dict = {}
for i in reproduced_bic_ids:
    de_shared[i]={}
    de = pd.read_csv("bic"+str(i)+"_UKE181.DE.tsv",sep = "\t")
    de = de.loc[de["adj.P.Val"]<p,:]
    de_up = de.loc[de["logFC"]>lfc,:].index.values
    de_down = de.loc[de["logFC"]<-lfc,:].index.values
    de2 = pd.read_csv("bic"+str(i)+"_DASL377.DE.tsv",sep = "\t")
    de2 = de2.loc[de2["adj.P.Val"]<p,:]
    de2_up = de2.loc[de2["logFC"]>lfc,:].index.values
    de2_down = de2.loc[de2["logFC"]<-lfc,:].index.values
    print("\t UKE bic.%s:"%i,len(de_up),len(de_down) )
    print("\t DASL bic.%s:"%i,len(de2_up),len(de2_down) )
    if uke_bics.loc[i,"direction"] == dasl_bics.loc[i,"direction"]:
        shared_up = set(de_up).intersection(set(de2_up))
        shared_down = set(de_down).intersection(set(de2_down))
    else:
        shared_up = set(de_up).intersection(set(de2_down))
        shared_down = set(de_down).intersection(set(de2_up))
    print("\t shared.%s:"%i,len(shared_up),len(shared_down) )
    de_shared[i]["genes"] = shared_up | shared_down
    de_shared[i]["genes_up"] = shared_up
    de_shared[i]["genes_down"] = shared_down
    print(i,len(shared_up | shared_down))
    query_gset_dict.update({"UKEbic"+str(i)+"_up":uke_bics.loc[i,"genes_up"],
                            "UKEbic"+str(i)+"_down":uke_bics.loc[i,"genes_down"],
                            "UKE"+str(i)+"_up":set(de_up),
                            "UKE"+str(i)+"_down":set(de_down)})
    query_gset_dict.update({"DASLbic"+str(i)+"_up":dasl_bics.loc[i,"genes_up"],
                            "DASLbic"+str(i)+"_down":dasl_bics.loc[i,"genes_down"],
                           "DASL"+str(i)+"_up":set(de2_up),
                            "DASL"+str(i)+"_down":set(de2_down)})
    query_gset_dict.update({"shared_"+str(i)+"_up":shared_up,"shared_"+str(i)+"_down":shared_down}
    )
de_shared=pd.DataFrame.from_dict(de_shared).T
#de_shared=de_shared.loc[reproduced_bic_ids,:]
de_shared
# Out:
# 	 UKE bic.84: 7 305
# 	 DASL bic.84: 12 37
# 	 shared.84: 1 13
# 84 14
#                                                 genes  \
# 84  {ENSG00000141096, ENSG00000176204, ENSG0000028...
#
#                                            genes_down           genes_up
# 84  {ENSG00000141096, ENSG00000176204, ENSG0000028...  {ENSG00000122133}

# %%
b = 84

# %%
#sorted(set(uke.index).intersection(uke_bics.loc[b,"genes"]))

# %%
from scipy.stats import fisher_exact

# %%
def read_limma(tsv_file,exprs):
    df = pd.read_csv(tsv_file,sep ="\t",index_col=0)
    #df = df.loc[df["adj.P.Val"]<0.05,:]
    cols = list(df.columns.values)
    df["gene"] = df.index
    df["gene"] = df["gene"].apply(lambda x: rename_gene(x))
    df = df.loc[:,["gene"]+cols]
    df = add_avg_exprs(df, exprs,col_name = "avgLog2exprs")
    df = df.sort_values(by="adj.P.Val" )
    df["rank"] = df["adj.P.Val"].rank()
    return df

def add_avg_exprs(df, exprs,col_name = "avgLog2exprs"):
    df[col_name ] = np.nan
    shared  =  sorted(set(df.index.values).intersection(set(exprs.index.values)))
    df.loc[shared,col_name ] = exprs.loc[shared ,:].mean(axis=1)
    return df

# %%
de_uke = read_limma("bic"+str(b)+"_UKE181.DE.tsv",exprs)
de_dasl = read_limma("bic"+str(b)+"_DASL377.DE.tsv",exprs_dasl)
shared_genes = set(exprs.index).intersection(set(exprs_dasl.index))
print("shared_genes",len(shared_genes))


de_uke  =de_uke.loc[de_uke["adj.P.Val"]<p,:]
de_uke  = de_uke.loc[de_uke["logFC"].abs()>lfc,:]

de_dasl  = de_dasl.loc[de_dasl["adj.P.Val"]<p,:]
de_dasl  = de_dasl.loc[de_dasl["logFC"].abs()>lfc,:]


uke_signif = set(de_uke.index)
dasl_signif = set(de_dasl.index)
print("all","signif. in UKE:",len(uke_signif),"in DASL:" , len(dasl_signif))
uke_signif = set(de_uke.index).intersection(shared_genes)
dasl_signif = set(de_dasl.index).intersection(shared_genes)
print("shared","signif. in UKE:",len(uke_signif),"in DASL:" , len(dasl_signif))

signif_both = set(de_uke.index).intersection(set(de_dasl.index))
signif_any = set(de_uke.index).union(set(de_dasl.index)).intersection(shared_genes)
print("significant in both",len(signif_both))
print("significant in at least one",len(signif_any))
o = len(signif_both)
uke_only = len(uke_signif.intersection(shared_genes))-len(signif_both)
dasl_only = len(dasl_signif.intersection(shared_genes))-len(signif_both)
print([[o, uke_only],[dasl_only, len(shared_genes) - uke_only - dasl_only - o ]])
statistics, pval = fisher_exact([[o, uke_only],[dasl_only, len(shared_genes) - uke_only - dasl_only + o ]], alternative="greater")
print("overlap p-value:%.2e"%pval )
# Out:
# shared_genes 15592
# all signif. in UKE: 312 in DASL: 49
# shared signif. in UKE: 118 in DASL: 46
# significant in both 14
# significant in at least one 150
# [[14, 104], [32, 15442]]
# overlap p-value:1.75e-19

# %%
de_uke = read_limma("bic"+str(b)+"_UKE181.DE.tsv",exprs)
de_dasl = read_limma("bic"+str(b)+"_DASL377.DE.tsv",exprs_dasl)

uke = de_uke.loc[:,:].copy()
uke["in bic."+str(b)] = 0
uke.loc[sorted(set(uke.index).intersection(uke_bics.loc[b,"genes"])),"in bic."+str(b)] = 1

uke = uke.loc[sorted(signif_any),["gene","in bic."+str(b),"logFC","adj.P.Val","avgLog2exprs","rank"]]
uke.columns = ["gene","in bic."+str(b)]+["UKE_"+x for x in ["logFC","adj.P.Val","avgLog2exprs","rank"]]

dasl = de_dasl.loc[sorted(signif_any),["logFC","adj.P.Val","avgLog2exprs","rank"]]
dasl.columns = ["DASL_"+x for x in dasl.columns]

df = pd.concat([uke,dasl],axis=1)
# check the sign of log2FC is the same
d = df.loc[df["UKE_logFC"]*df["DASL_logFC"]<0,:]
if d.shape[0]>0:
    print("the sign does not match:")
    print(len(set(d.index).intersection(shared_genes)))

# keep only DE genes with the same lFC sign
df = df.loc[df["UKE_logFC"]*df["DASL_logFC"]>0,:]

d = df.loc[df["UKE_logFC"].abs()>=lfc,:]
d = d.loc[d["UKE_adj.P.Val"]<p,:]
uke_signif = set(d.index)

d = df.loc[df["DASL_logFC"].abs()>=lfc,:]
d = d.loc[d["DASL_adj.P.Val"]<p,:]
dasl_signif = set(d.index)
print("signif. in UKE:",len(uke_signif),"signif. in in DASL:" , len(dasl_signif))
signif_both = uke_signif.intersection(dasl_signif)
signif_any = uke_signif.union(dasl_signif)#.intersection(shared_genes)
print("significant in both",len(signif_both))
print("significant in at least one dataset",len(signif_any))

df["avg_rank"] = df.loc[:,["UKE_rank","DASL_rank"]].mean(axis=1)
df = df.sort_values("avg_rank")
# logFC sign is  flipped to compare benefit vs no benefit groups
df["UKE_logFC"] = df["UKE_logFC"] * -1
df["DASL_logFC"] = df["DASL_logFC"] * -1
df.index.names = ["gene_id"]
###df.to_csv("tables/bic"+str(b)+"_DE.UKE_and_DASL.tsv",sep="\t")
df.head(20)
# Out:
# the sign does not match:
# 17
# signif. in UKE: 103 signif. in in DASL: 44
# significant in both 14
# significant in at least one dataset 133
#                       gene  in bic.84  UKE_logFC  UKE_adj.P.Val  \
# gene_id
# ENSG00000205359    SLCO6A1          1   3.610710   6.827249e-40
# ENSG00000084453    SLCO1A2          0   2.597286   5.831795e-08
# ENSG00000144407      PTH2R          1   2.918521   9.135928e-07
# ENSG00000127928      GNGT1          0   1.926976   5.165309e-07
# ENSG00000133710     SPINK5          0   1.976104   1.730418e-07
# ENSG00000176204     LRRTM4          0   1.873221   1.084620e-04
# ENSG00000124092      CTCFL          0   2.054593   5.926518e-04
# ENSG00000280409  LINC01101          0   1.224104   1.341776e-03
# ENSG00000267313                     0   2.385125   1.080929e-05
# ENSG00000162782      TDRD5          0   1.239632   2.582152e-04
# ENSG00000198054      DSCR8          0   1.526098   4.379622e-03
# ENSG00000130294      KIF1A          0   1.447636   6.010922e-03
# ENSG00000125788    DEFB126          0   2.097391   4.748390e-06
# ENSG00000081148      IMPG2          0   1.360798   4.057864e-03
# ENSG00000049089     COL9A2          0   1.078848   2.753490e-03
# ENSG00000118137      APOA1          0   1.721665   1.075617e-03
# ENSG00000173157   ADAMTS20          0   1.542703   1.088444e-03
# ENSG00000196421  C20orf204          0   1.003921   2.645426e-03
# ENSG00000184697      CLDN6          0   1.739295   1.176312e-02
# ENSG00000148942    SLC5A12          0   1.868516   2.924901e-06
#
#                  UKE_avgLog2exprs  UKE_rank  DASL_logFC  DASL_adj.P.Val  \
# gene_id
# ENSG00000205359          2.401567       2.0    1.930636    5.788021e-33
# ENSG00000084453          4.685145      20.0    1.081157    3.788957e-13
# ENSG00000144407          5.776959      36.0    3.935389    1.469472e-86
# ENSG00000127928          5.084154      35.0    1.381456    3.006943e-13
# ENSG00000133710          6.814876      26.0    1.040379    8.840066e-07
# ENSG00000176204          2.435715      96.0    1.027032    1.230601e-07
# ENSG00000124092          7.741535     135.0    1.576616    3.686130e-07
# ENSG00000280409          3.846328     183.0    1.643674    4.389658e-10
# ENSG00000267313          2.741302      61.0    0.479585    1.998411e-05
# ENSG00000162782          5.737292     116.0    0.576361    8.758303e-06
# ENSG00000198054          1.156431     290.5    1.615826    3.478067e-07
# ENSG00000130294          9.589828     343.5    0.923626    6.235629e-08
# ENSG00000125788          1.999686      56.5    0.623778    1.113310e-04
# ENSG00000081148          6.305114     279.0    0.716407    2.812878e-06
# ENSG00000049089          9.850702     232.0    0.952534    1.108301e-05
# ENSG00000118137          7.285786     163.5    0.606339    5.704680e-05
# ENSG00000173157          2.994106     165.5    0.658405    6.798002e-05
# ENSG00000196421          7.676519     228.0    0.790367    2.646084e-05
# ENSG00000184697          7.819388     444.0    1.424398    3.053677e-06
# ENSG00000148942          4.302759      48.0    0.454791    4.101983e-04
#
#                  DASL_avgLog2exprs  DASL_rank  avg_rank
# gene_id
# ENSG00000205359           7.656167        2.0      2.00
# ENSG00000084453           6.121194        5.0     12.50
# ENSG00000144407           9.507736        1.0     18.50
# ENSG00000127928           7.939428        4.0     19.50
# ENSG00000133710          10.245764       83.0     54.50
# ENSG00000176204           7.997956       31.5     63.75
# ENSG00000124092          11.021222       51.0     93.00
# ENSG00000280409           9.318886       12.0     97.50
# ENSG00000267313           6.795675      218.0    139.50
# ENSG00000162782           6.246956      167.0    141.50
# ENSG00000198054           9.448314       47.5    169.00
# ENSG00000130294          14.165411       24.0    183.75
# ENSG00000125788           6.081677      350.0    203.25
# ENSG00000081148           8.004106      130.5    204.75
# ENSG00000049089          12.305211      183.0    207.50
# ENSG00000118137          13.188413      281.0    222.25
# ENSG00000173157           6.863106      294.0    229.75
# ENSG00000196421          12.222119      239.0    233.50
# ENSG00000184697          13.767476      132.5    288.25
# ENSG00000148942           5.753650      551.0    299.50

# %%
df.loc[[x for x in df.index if x in signif_both],:].head(20)
# Out:
#                       gene  in bic.84  UKE_logFC  UKE_adj.P.Val  \
# gene_id
# ENSG00000205359    SLCO6A1          1   3.610710   6.827249e-40
# ENSG00000084453    SLCO1A2          0   2.597286   5.831795e-08
# ENSG00000144407      PTH2R          1   2.918521   9.135928e-07
# ENSG00000127928      GNGT1          0   1.926976   5.165309e-07
# ENSG00000133710     SPINK5          0   1.976104   1.730418e-07
# ENSG00000176204     LRRTM4          0   1.873221   1.084620e-04
# ENSG00000124092      CTCFL          0   2.054593   5.926518e-04
# ENSG00000280409  LINC01101          0   1.224104   1.341776e-03
# ENSG00000198054      DSCR8          0   1.526098   4.379622e-03
# ENSG00000184697      CLDN6          0   1.739295   1.176312e-02
# ENSG00000112280     COL9A1          0   1.675043   1.424517e-02
# ENSG00000122133       PAEP          0  -1.411878   2.939629e-02
# ENSG00000124260    MAGEA10          0   1.595592   1.161979e-02
# ENSG00000141096      DPEP3          0   2.004827   2.908896e-02
#
#                  UKE_avgLog2exprs  UKE_rank  DASL_logFC  DASL_adj.P.Val  \
# gene_id
# ENSG00000205359          2.401567       2.0    1.930636    5.788021e-33
# ENSG00000084453          4.685145      20.0    1.081157    3.788957e-13
# ENSG00000144407          5.776959      36.0    3.935389    1.469472e-86
# ENSG00000127928          5.084154      35.0    1.381456    3.006943e-13
# ENSG00000133710          6.814876      26.0    1.040379    8.840066e-07
# ENSG00000176204          2.435715      96.0    1.027032    1.230601e-07
# ENSG00000124092          7.741535     135.0    1.576616    3.686130e-07
# ENSG00000280409          3.846328     183.0    1.643674    4.389658e-10
# ENSG00000198054          1.156431     290.5    1.615826    3.478067e-07
# ENSG00000184697          7.819388     444.0    1.424398    3.053677e-06
# ENSG00000112280          5.954088     511.5    1.139113    3.545447e-05
# ENSG00000122133          5.538539     844.0   -1.297273    3.434086e-06
# ENSG00000124260          1.848648     440.0    1.008335    2.008458e-03
# ENSG00000141096          3.791042     839.0    1.010375    6.539803e-03
#
#                  DASL_avgLog2exprs  DASL_rank  avg_rank
# gene_id
# ENSG00000205359           7.656167        2.0      2.00
# ENSG00000084453           6.121194        5.0     12.50
# ENSG00000144407           9.507736        1.0     18.50
# ENSG00000127928           7.939428        4.0     19.50
# ENSG00000133710          10.245764       83.0     54.50
# ENSG00000176204           7.997956       31.5     63.75
# ENSG00000124092          11.021222       51.0     93.00
# ENSG00000280409           9.318886       12.0     97.50
# ENSG00000198054           9.448314       47.5    169.00
# ENSG00000184697          13.767476      132.5    288.25
# ENSG00000112280           8.837493      249.5    380.50
# ENSG00000122133           7.944843      138.0    491.00
# ENSG00000124260           8.458861     1012.5    726.25
# ENSG00000141096          11.510844     1558.5   1198.75

# %%
xls_flie = 'tables/S3_DE_genes_p-value'+str(p)+'_lfc'+str(lfc)+'.xlsx'
print(xls_flie)
# Out:
# tables/S3_DE_genes_p-value0.05_lfc1.xlsx

# %% [markdown]
# ### bic. 84: genes DE in both UKE and DASL
#
# Fig. 3

# %%
fs = 12
i = [84]#eproduced_bic_ids
b = uke_bics.loc[i,:].copy()
b["genes"] = de_shared["genes"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
b["genes_up"] = de_shared["genes_up"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
b["genes_down"] = de_shared["genes_down"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))


fig = draw_heatmap2(exprs_z_rn.loc[:,annot.index], b,
                    annot=uke_subt.loc[:,["subtype", "Bentink"]],
                    color_dict=color_dict,
              bicluster_colors="redblue",
              figsize = (4,3), 
              dendrogram_ratio=(0.05,0.05),
              colors_ratio=(0.03, 0.05),
              bic_prefix = "b.",
              legend_n_cols=0,
              no_cbar=True,
              col_labels = False,
              row_labels = True,
              color_range=(-3,3),
              highlight_row_labels=['PTH2R', 'SLCO6A1', 'LINC01456', 'ENSG00000249721', 'LINC00491',#"PTH2R","SLCO6A1",
              "ADIPOQ","CIDEA","CIDEC","PLIN1","CD300LG"],
                no_row_colors = True,cluster_rows=False
             )
ax = fig[0].ax_heatmap
tmp = ax.set_xlabel("UKE, n=%s samples"%annot.shape[0], fontsize=fs)
plt.show()

# %%
de_shared["genes_down"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes])).values
# Out:
# array([{'MAGEA10', 'CLDN6', 'CTCFL', 'LINC01101', 'LRRTM4', 'COL9A1', 'SPINK5', 'DSCR8', 'GNGT1', 'SLCO6A1', 'PTH2R', 'DPEP3', 'SLCO1A2'}],
#       dtype=object)

# %%
b = dasl_bics.loc[i,:].copy()
b["genes"] = de_shared["genes"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
b["genes_up"] = de_shared["genes_up"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))
b["genes_down"] = de_shared["genes_down"].apply(lambda genes: set([rename_gene(x, keep_not_mapped=True) for x in genes]))

fig = draw_heatmap2(exprs_z_rn_dasl.loc[:,annot_dasl.index], b,
                    annot=dasl_subt.loc[:,["subtype", "Bentink"]],
                    color_dict=color_dict,
                    bicluster_colors="redblue",
                    figsize = (4,3), 
                    dendrogram_ratio=(0.05,0.05),
                    colors_ratio=(0.03, 0.05),
                    bic_prefix = "b. ",
                    legend_n_cols=0,
                    no_cbar=True,
                    col_labels = False,
                    row_labels = True,
                    color_range=(-3,3),
                    highlight_row_labels=['PTH2R', 'SLCO6A1', 'LINC01456', 'ENSG00000249721', 'LINC00491',#"PTH2R","SLCO6A1",
                    "ADIPOQ","CIDEA","CIDEC","PLIN1","CD300LG"],
                    no_row_colors = True,cluster_rows=False
             )
ax = fig[0].ax_heatmap
tmp = ax.set_xlabel("DASL, n=%s samples"%annot_dasl.shape[0], fontsize=fs)
plt.show()

# %% [markdown]
# ## Gene set overrepresentation

# %%
# only genes presenting in both UKE and DASL are accounted
import gseapy
names = gseapy.get_library_name()

#annot = pd.read_csv("../data/UKE.sample_annotation_v4_181samples.tsv",sep ="\t",index_col=0)
shared_samples = sorted(set(exprs.columns.values).intersection(set(annot.index.values)))
shared_genes = sorted(set(exprs.index.values).intersection(set(exprs_dasl.index.values)))
#exprs = exprs.loc[:,shared_samples]
#annot = annot.loc[shared_samples,:]

bg_gene_names = [rename_gene(x) for x in shared_genes if len(rename_gene(x))>0]
bg_gene_names = sorted(bg_gene_names)
exprs_g_names = exprs.loc[:,:].copy()
exprs_g_names.index = [rename_gene(x,keep_not_mapped=True) for x in exprs.index.values]
exprs_g_names = exprs_g_names.loc[bg_gene_names,:]
print(len(bg_gene_names))
# Out:
# 15578

# %%
gset_dbs = ['GO_Molecular_Function_2023', 
            'GO_Biological_Process_2023',
            'Reactome_2022',
            'WikiPathway_2023_Human',
            'KEGG_2021_Human',
            'CORUM',
            'GTEx_Tissues_V8_2023',
            'CellMarker_2024',
            'Descartes_Cell_Types_and_Tissue_2021',
            'Tabula_Sapiens']

gset_stats  = {}
## download databases, extract datasets, overlap with background
for db in gset_dbs:
    gset_stats[db] = {}
    gset_db = gseapy.get_library(name=db, organism='human')
    print(db, len(gset_db.keys()))
    for gs in gset_db.keys():
        gset = gset_db[gs]
        gset_exprs = set(gset).intersection(set(bg_gene_names))
        #print(db, gs, len(gset),len(gset_exprs), gset_exprs)
        gset_stats[db][gs] = gset_exprs

# %%
from openpyxl import load_workbook

xls_flie = 'tables/S4AB_ORA_p'+str(p)+'_lfc'+str(lfc)+'.xlsx'

with pd.ExcelWriter(xls_flie, engine='openpyxl') as writer:
    if not os.path.exists(xls_flie):
        pd.DataFrame().to_excel(writer, engine='openpyxl', sheet_name= "description")

    gso_bic = []
    for b in [84,130]:
        de = pd.read_csv("tables/bic"+str(b)+"_DE.UKE_and_DASL.tsv",sep="\t",index_col=0)
        de = de.loc[de["UKE_adj.P.Val"]<0.05,:]
        de = de.loc[de["DASL_adj.P.Val"]<0.05,:]
        if b == 84:
            de = de.loc[de["UKE_logFC"]>1,:]
            de = de.loc[de["DASL_logFC"]>1,:]
        if b == 130:
            de = de.loc[de["UKE_logFC"]<-1,:]
            de = de.loc[de["DASL_logFC"]<-1,:]
        gene_list = [x for x in list(de["gene"].values) if type(x)==str]
        gp_output = gseapy.enrichr(gene_list=gene_list,
                                   gene_sets=gset_dbs,
                                   organism="human",
                                   background=bg_gene_names,
                                   outdir="gseapy/",
                                   no_plot=True
                                  )
        res = gp_output.results
        res = res.loc[res["Adjusted P-value"]<0.05,:].copy()

        res['genes'] =  res['Genes'].apply(lambda x: " ".join(sorted(x.split(";"))))
        try:
            res["db_gset_size"] = res.apply(lambda x: len(gset_stats[x["Gene_set"]][x["Term"]]),axis=1)
        except:
            res["db_gset_size"] = np.nan
        res["overlap_size"] =  res['Genes'].apply(lambda x: len(sorted(x.split(";"))))

        res['bicluster_id'] = b
        cols = ['bicluster_id','Gene_set', 'Term',  'P-value', 'Adjusted P-value', 'Odds Ratio', 'Combined Score',
                'overlap_size', 'db_gset_size', 'genes']
        res = res.loc[res["overlap_size"]>1,cols]
        res["Gene_set_collection"] = res["Gene_set"]
        res["gene_set_name"] = res["Term"]

        cols = ['Gene_set_collection', 'gene_set_name', 'P-value', 'Adjusted P-value', 'Odds Ratio', 'overlap_size', 'genes']
        res = res.loc[:,cols].drop_duplicates(subset=["genes","Gene_set_collection"])
        res = res.sort_values(by = ["Adjusted P-value","Odds Ratio","genes","Gene_set_collection"],
                                ascending  = [True, False,True, True])
        res["bicluster"] = b
        gso_bic.append(res.loc[:,cols].copy())
        res = res.set_index("gene_set_name")
        print( "bic."+str(b), "genes in query set:",len(gene_list),"DB gene sets passed:", res.shape[0])
        ###res.to_excel(writer, engine='openpyxl', sheet_name= "bic."+str(b))

gso_bic = pd.concat(gso_bic)
gso_bic
# Out:
# bic.84 genes in query set: 13 DB gene sets passed: 6
# bic.130 genes in query set: 101 DB gene sets passed: 306
#              Gene_set_collection  \
# 245         GTEx_Tissues_V8_2023
# 0     GO_Molecular_Function_2023
# 22    GO_Biological_Process_2023
# 246         GTEx_Tissues_V8_2023
# 75                 Reactome_2022
# ...                          ...
# 1930             CellMarker_2024
# 240   GO_Biological_Process_2023
# 241   GO_Biological_Process_2023
# 242   GO_Biological_Process_2023
# 244   GO_Biological_Process_2023
#
#                                           gene_set_name   P-value  \
# 245                                Testis Male 50-59 Up  0.000004
# 0     Sodium-Independent Organic Anion Transmembrane...  0.000035
# 22    Sodium-Independent Organic Anion Transport (GO...  0.000035
# 246                                Testis Male 20-29 Up  0.000377
# 75    Anti-inflammatory Response Favoring Leishmania...  0.000121
# ...                                                 ...       ...
# 1930                      Endothelial Cell Artery Mouse  0.008835
# 240   Positive Regulation Of Cell Adhesion Mediated ...  0.005312
# 241       Energy Reserve Metabolic Process (GO:0006112)  0.005312
# 242         Antimicrobial Humoral Response (GO:0019730)  0.005436
# 244   Glycosaminoglycan Biosynthetic Process (GO:000...  0.005436
#
#       Adjusted P-value  Odds Ratio  overlap_size                genes
# 245           0.000251  125.902703             3  CTCFL DPEP3 MAGEA10
# 0             0.000775  314.262626             2      SLCO1A2 SLCO6A1
# 22            0.001866  314.262626             2      SLCO1A2 SLCO6A1
# 246           0.007573   85.575758             2        CTCFL MAGEA10
# 75            0.014822   39.610256             3    DPEP3 GNGT1 PTH2R
# ...                ...         ...           ...                  ...
# 1930          0.047745   15.613131             2         CXCL12 FABP4
# 240           0.047839   20.824242             2          CCL21 SFRP2
# 241           0.047839   20.824242             2            GFPT2 LEP
# 242           0.047839    9.080651             3   CTSG CXCL14 JCHAIN
# 244           0.047839    9.080651             3      HAS1 HAS2 XYLT1
#
# [312 rows x 7 columns]

# %%
gset_dbs2 = ['GO_Molecular_Function_2023',
 'Reactome_2022',
 'WikiPathway_2023_Human',
 'KEGG_2021_Human',
 'GTEx_Tissues_V8_2023',
 'CellMarker_2024',
 'Descartes_Cell_Types_and_Tissue_2021',
 'Tabula_Sapiens']

# %%
xls_flie = 'tables/S4CD_GSEA_p'+str(p)+'_lfc'+str(lfc)+'.xlsx'

# %%
### GSEA
gsea_results = {}
for bic_id in reproduced_bic_ids:
    # make cls files
    #design = pd.read_csv("UKE_181.design.tsv",sep ="\t",index_col=0)
    #design = design.loc[:,["bic"+str(bic_id)]] 
    #exprs_g_names = exprs_g_names.loc[:,design.index]
    design = pd.read_csv("DASL_377.design.tsv",sep ="\t",index_col=0)
    design = design.loc[:,["bic"+str(bic_id)]] 
    exprs_g_names = exprs_dasl.loc[:,:].copy()
    exprs_g_names.index = [rename_gene(x,keep_not_mapped=True) for x in exprs_dasl.index.values]
    exprs_g_names = exprs_g_names.loc[bg_gene_names,:]
    
    groups = list(design["bic"+str(bic_id)].values)
    gr1, gr2 = 1, 0
    cls_file = 'bic'+str(bic_id)+'.cls'
    with open(cls_file, "w") as cl:
        line = f"{len(groups)} 2 1\n# "+str(gr1)+" "+str(gr2)+"\n"
        cl.write(line)
        cl.write(" ".join(map(str,groups)) + "\n")
        
    print("Gene set:", bic_id)
    # run gsea
    bic_gsea_results = []
    for db in gset_dbs2:
        print(db)
        gsea_res = gseapy.gsea(data=exprs_g_names, 
                     gene_sets=db,
                     cls= cls_file, 
                     permutation_type='phenotype',
                     permutation_num=1000, # reduce number to speed up test
                     max_size=200, min_size=5, # min and max DB gene set sizes
                     outdir=None,  # do not write output to disk
                     method='signal_to_noise',
                     seed=0,verbose=True)
        res = gsea_res.res2d.loc[:,:].copy()
        res["genes"] = res["Lead_genes"].apply(lambda x: " ".join(x.split(";")))
        res["overlap_size"] = res["Lead_genes"].apply(lambda x: len(x.split(";")))
        res["DB"] = db
        res["query_gene_set"] = bic_id
        bic_gsea_results.append(res)
    bic_gsea_results = pd.concat(bic_gsea_results,axis=0).sort_values(by = "FDR q-val")
    gsea_results[bic_id] = bic_gsea_results
# Out:
# 2025-02-13 15:16:30,822 [INFO] Parsing data files for GSEA.............................
# Gene set: 84
# GO_Molecular_Function_2023
# 2025-02-13 15:16:32,617 [INFO] Enrichr library gene sets already downloaded in: /home/olya/.cache/gseapy, use local file
# 2025-02-13 15:16:32,640 [INFO] 0131 gene_sets have been filtered out when max_size=200 and min_size=5
# 2025-02-13 15:16:32,641 [INFO] 1016 gene_sets used for further statistical testing.....
# 2025-02-13 15:16:32,642 [INFO] Start to run GSEA...Might take a while..................
# 2025-02-13 15:18:53,551 [INFO] Congratulations. GSEApy ran successfully.................
#
# 2025-02-13 15:18:53,564 [INFO] Parsing data files for GSEA.............................
# Reactome_2022
# 2025-02-13 15:18:56,328 [INFO] Enrichr library gene sets already downloaded in: /home/olya/.cache/gseapy, use local file
# 2025-02-13 15:18:56,389 [INFO] 0127 gene_sets have been filtered out when max_size=200 and min_size=5
# 2025-02-13 15:18:56,390 [INFO] 1691 gene_sets used for further statistical testing.....
# 2025-02-13 15:18:56,390 [INFO] Start to run GSEA...Might take a while..................
# 2025-02-13 15:23:39,335 [INFO] Congratulations. GSEApy ran successfully.................
#
# 2025-02-13 15:23:39,538 [INFO] Parsing data files for GSEA.............................
# WikiPathway_2023_Human
# 2025-02-13 15:23:41,570 [INFO] Enrichr library gene sets already downloaded in: /home/olya/.cache/gseapy, use local file
# 2025-02-13 15:23:41,596 [INFO] 0036 gene_sets have been filtered out when max_size=200 and min_size=5
# 2025-02-13 15:23:41,597 [INFO] 0765 gene_sets used for further statistical testing.....
# 2025-02-13 15:23:41,598 [INFO] Start to run GSEA...Might take a while..................
# 2025-02-13 15:26:16,201 [INFO] Congratulations. GSEApy ran successfully.................
#
# 2025-02-13 15:26:16,476 [INFO] Parsing data files for GSEA.............................
# KEGG_2021_Human
# 2025-02-13 15:26:18,227 [INFO] Enrichr library gene sets already downloaded in: /home/olya/.cache/gseapy, use local file
# 2025-02-13 15:26:18,247 [INFO] 0020 gene_sets have been filtered out when max_size=200 and min_size=5
# 2025-02-13 15:26:18,249 [INFO] 0300 gene_sets used for further statistical testing.....
# 2025-02-13 15:26:18,249 [INFO] Start to run GSEA...Might take a while..................
# 2025-02-13 15:27:24,019 [INFO] Congratulations. GSEApy ran successfully.................
#
# 2025-02-13 15:27:24,131 [INFO] Parsing data files for GSEA.............................
# GTEx_Tissues_V8_2023
# 2025-02-13 15:27:25,693 [INFO] Enrichr library gene sets already downloaded in: /home/olya/.cache/gseapy, use local file
# 2025-02-13 15:27:25,717 [INFO] 0000 gene_sets have been filtered out when max_size=200 and min_size=5
# 2025-02-13 15:27:25,718 [INFO] 0511 gene_sets used for further statistical testing.....
# 2025-02-13 15:27:25,718 [INFO] Start to run GSEA...Might take a while..................
# 2025-02-13 15:29:03,988 [INFO] Congratulations. GSEApy ran successfully.................
#
# 2025-02-13 15:29:04,037 [INFO] Parsing data files for GSEA.............................
# CellMarker_2024
# 2025-02-13 15:29:05,647 [INFO] Enrichr library gene sets already downloaded in: /home/olya/.cache/gseapy, use local file
# 2025-02-13 15:29:05,714 [INFO] 0210 gene_sets have been filtered out when max_size=200 and min_size=5
# 2025-02-13 15:29:05,715 [INFO] 1482 gene_sets used for further statistical testing.....
# 2025-02-13 15:29:05,716 [INFO] Start to run GSEA...Might take a while..................
# 2025-02-13 15:33:22,204 [INFO] Congratulations. GSEApy ran successfully.................
#
# 2025-02-13 15:33:22,279 [INFO] Parsing data files for GSEA.............................
# Descartes_Cell_Types_and_Tissue_2021
# 2025-02-13 15:33:24,126 [INFO] Enrichr library gene sets already downloaded in: /home/olya/.cache/gseapy, use local file
# 2025-02-13 15:33:24,142 [INFO] 0018 gene_sets have been filtered out when max_size=200 and min_size=5
# 2025-02-13 15:33:24,143 [INFO] 0154 gene_sets used for further statistical testing.....
# 2025-02-13 15:33:24,144 [INFO] Start to run GSEA...Might take a while..................
# 2025-02-13 15:34:07,738 [INFO] Congratulations. GSEApy ran successfully.................
#
# 2025-02-13 15:34:07,962 [INFO] Parsing data files for GSEA.............................
# Tabula_Sapiens
# 2025-02-13 15:34:09,465 [INFO] Enrichr library gene sets already downloaded in: /home/olya/.cache/gseapy, use local file
# 2025-02-13 15:34:09,497 [INFO] 0000 gene_sets have been filtered out when max_size=200 and min_size=5
# 2025-02-13 15:34:09,499 [INFO] 0469 gene_sets used for further statistical testing.....
# 2025-02-13 15:34:09,499 [INFO] Start to run GSEA...Might take a while..................
# 2025-02-13 15:35:41,616 [INFO] Congratulations. GSEApy ran successfully.................

# %%
cols = ['DB', 'Term', 'ES', 'NES', 'NOM p-val', 'FDR q-val', 'FWER p-val',
       #'Tag %', 'Gene %', 'query_gene_set'
        'Lead_genes', 'genes', 'overlap_size',
       ]
ds = "DASL"
with pd.ExcelWriter("tables/GSEA_"+ds+"_biclusters.xlsx", engine='openpyxl') as writer:
    if not os.path.exists(xls_flie):
        pd.DataFrame().to_excel(writer, engine='openpyxl', sheet_name= "description")
    for bic_id in reproduced_bic_ids:
        df = gsea_results[bic_id]
        df = df.sort_values(by = ["FDR q-val"],ascending  = [True])
        print("Tested gene sets:", df.shape[0])
        df = df.loc[df["FDR q-val"]<0.05,:]
        print("Passed gene sets:", df.shape[0])
        df = df.loc[:,cols]
        if df.shape[0]>0:
            df = df.set_index("Term")
            df.to_excel(writer,  engine='openpyxl', sheet_name= "bic."+str(bic_id))
            writer.save()
# Out:
# Tested gene sets: 6388
# Passed gene sets: 0

# %% [markdown]
# # Prognostic value

# %%
s = "OS"
s, sele_bics_ids
# Out:
# ('OS', [70, 84, 130, 90, 109])

# %%
from bic_survival_tests import test_biclusters_prognostic
from bic_survival_plots import plot_KM_prognostic

min_n_samples = 10
tr = 1 # 1 - beva , 0 - standard

cols = covariates+[s+"_event",s+"_time"]
surv_data = annot.copy().loc[annot["bevacizumab"]==tr,cols]

stats = test_biclusters_prognostic(uke_bics.copy().loc[sele_bics_ids,:],
                                   surv_data,
                                   surv_event = s +"_event",
                                   surv_time = s +"_time",
                                   covariates = covariates,
                                   min_n_samples=min_n_samples)
stats.loc[stats["adj_pval"]<fdr,:]
# Out:
#      n_up  n_down        HR      CI_l      CI_r      pval  adj_pval
# 84   39.0    28.0  0.396212  0.192884  0.813875  0.011712  0.036359
# 70   44.0    23.0  3.402823  1.274244  9.087121  0.014544  0.036359
# 90   34.0    33.0  1.736877  0.853550  3.534345  0.127732  0.212887
# 130  32.0    35.0  1.523793  0.656961  3.534371  0.326479  0.408098
# 109  28.0    39.0  1.064701  0.527341  2.149633  0.861165  0.861165

# %%
plot_KM_prognostic(uke_bics.loc[[130,84,70],:].copy(),
                   surv_data.copy(),
                   stats.copy(),
                   treatment ="bevacizumab", #
                   #treatment = "standard", #
                   surv_time=s+'_time',
                   surv_event=s+'_event',
                   xlabel= s+", months",
                   cohort = "UKE",
                   #linestyle="dashed",
                   add_counts=True,
                   figsize = (4,3.5),
                   # figsize=(3,2)
                  )
# Out:
# 130 67 32 35
# 84 67 39 28
# 70 67 44 23

# %% [markdown]
# ### DASL

# %%
cols = covariates+[s+"_event",s+"_time"]
surv_data = annot_dasl.copy().loc[annot_dasl["bevacizumab"]==tr,cols]

stats = test_biclusters_prognostic(dasl_bics.copy().loc[sele_bics_ids,:],
                                   surv_data,
                                   surv_event = s +"_event",
                                   surv_time = s +"_time",
                                   covariates = covariates,
                                   min_n_samples=min_n_samples)
stats.loc[stats["adj_pval"]<fdr,:]
# Out:
#       n_up  n_down        HR      CI_l      CI_r      pval  adj_pval
# 130   24.0   174.0  2.866639  1.649579  4.981647  0.000188  0.000938
# 84   101.0    97.0  0.651206  0.429929  0.986371  0.042894  0.107234
# 109   40.0   158.0  1.331765  0.821514  2.158939  0.245097  0.379873
# 70    69.0   129.0  1.243917  0.820509  1.885818  0.303898  0.379873
# 90    94.0   104.0  1.197381  0.792601  1.808880  0.392132  0.392132

# %%
plot_KM_prognostic(dasl_bics.loc[[130,84,70] ,:],
                   surv_data,
                   stats,
                   treatment ="bevacizumab", #
                   #treatment ="standard", #
                   surv_time=s+'_time',
                   surv_event=s+'_event',
                   xlabel= s+", months",
                   cohort = "DASL",
                   #linestyle="dashed",
                   add_counts=True,
                   figsize = (4,3.5),
                  )
# Out:
# 130 198 24 174
# 84 198 101 97
# 70 198 69 129

# %%
from bic_survival_plots import plot_KM_four
    
bic_id = 70 # 70
figsize = (5.5,3)
bic_samples = uke_bics.loc[bic_id,"samples"].intersection(set(annot.index.values))
d = uke_bics.loc[bic_id,"direction"]   

s = "OS"

plot_KM_four(bic_samples,
             annot, bic_id, 
             d,
             surv_time = s+"_time",
             surv_event= s+"_event",
             cohort = "UKE, ",
             add_counts=True,
             figsize=figsize,
             label_pos=(110,0.35),
              add_subplot=True
            )
# Out:
# /home/olya/TUM/DESMOND/DESMOND2/OV_cancer_final/bevacizumab_ovca_signature/bic_survival_plots.py:310: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   linestyle='dashed',

# %%
bic_samples = dasl_bics.loc[bic_id,"samples"].intersection(set(annot_dasl.index.values))
d = dasl_bics.loc[bic_id,"direction"]   

plot_KM_four(bic_samples,
             annot_dasl, bic_id, d,
             surv_time = s+"_time",
             surv_event= s+"_event",
             cohort = "DASL, ",
             add_counts=True,
             figsize=figsize,
             label_pos=(110,0.35),
            add_subplot=True)
# Out:
# /home/olya/TUM/DESMOND/DESMOND2/OV_cancer_final/bevacizumab_ovca_signature/bic_survival_plots.py:310: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   linestyle='dashed',
