# %%
import pandas as pd
import numpy as np
import os,sys

import seaborn as sns
import matplotlib.pyplot as plt
from aux import fitCPH_and_plotKM_treatments

# %matplotlib inline

# %%
import lifelines
lifelines.__version__
# Out:
# '0.27.7'

# %% [markdown]
# # UKE

# %%
annot = pd.read_csv("../data/UKE.sample_annotation_v4_181samples.tsv",sep ="\t",index_col=0)
annot.head(2)
# Out:
#            patient_id  tumor_id  bevacizumab  standard   age  FIGO_I-IIIB  \
# sample_id
# T0063               1        63            0         1  53.0            0
# T0096               2        96            0         1  43.0            0
#
#            FIGO_IIIC  FIGO_IV  OP_0  OP_1  OP_2  OS_time  OS_event  PFS_time  \
# sample_id
# T0063              1        0     0     1     0     39.0       1.0       8.0
# T0096              1        0     1     0     0     61.0       1.0      59.0
#
#            PFS_event
# sample_id
# T0063            1.0
# T0096            1.0

# %%
max_time = 100 # limit for plots, does not affect stat. analysis

# to censor data by month 100, uncomment the next line
#annot = pd.read_csv("data/UKE.sample_annotation_v4_181samples.tsv",sep ="\t",index_col=0)

covariates = ["age","FIGO_IIIC","FIGO_IV","OP_1","OP_2", "bevacizumab"]

# %%
surv = "OS"
surv_event=surv+"_event"
surv_time=surv+"_time"

fitCPH_and_plotKM_treatments(annot,
                  surv_event=surv_event,
                  surv_time=surv_time,
                  covariates=covariates,
                  figsize=(5,4),
                  add_risk_counts=True,
                  max_time=100,
                  title = "%s  (n=%s), %s, months"%("UKE",annot.shape[0],surv),
                  fig_file = "../img/Fig1A.pdf")
# Out:
# p-value=0.02
# HR=0.61(0.40-0.92)

# %%
surv = "PFS"
surv_event=surv+"_event"
surv_time=surv+"_time"

fitCPH_and_plotKM_treatments(annot,
                  surv_event=surv_event,
                  surv_time=surv_time,
                  covariates=covariates,
                  figsize=(5,4),
                  max_time=100,
                  title = "%s  (n=%s), %s, months"%("UKE",annot.shape[0],surv),
                  fig_file = "../img/Fig1B.pdf")
# Out:
# p-value=0.10
# HR=0.75(0.53-1.06)

# %% [markdown]
# # DASL

# %%
annot_dasl = pd.read_csv("../data/DASL.annotation_Kommoss.tsv.gz",sep ="\t",index_col=0)
print(annot_dasl.shape[0])
annot_dasl.head(2)
# Out:
# 377
#                bevacizumab  chemo_only  is_HGSOC FIGO_code  FIGO_IV  \
# sample_id
# X5800701055_A            0           1         1        IV        1
# X5800701055_B            0           1         1        IV        1
#
#                FIGO_I-IIIB  FIGO_IIIC  FIGO_1  FIGO_2  FIGO_3  ...  PFS_event  \
# sample_id                                                      ...
# X5800701055_A            0          0       0       0       0  ...          0
# X5800701055_B            0          0       0       0       0  ...          1
#
#                 PFS_time  treatment  age  is_HGSOC_GEO OS_event_GEO  \
# sample_id
# X5800701055_A  71.590792   standard   47             0            0
# X5800701055_B  10.743547   standard   65             1            1
#
#                OS_time_GEO  PFS_event_GEO  PFS_time_GEO          subtype
# sample_id
# X5800701055_A    43.594521              0     43.594521   immunoreactive
# X5800701055_B    26.169863              1     10.750685    proliferative
#
# [2 rows x 30 columns]

# %%
surv = "OS"
surv_event=surv+"_event"
surv_time=surv+"_time"

fitCPH_and_plotKM_treatments(annot_dasl,
                  surv_event=surv_event,
                  surv_time=surv_time,
                  covariates=covariates,
                  figsize=(5,4),
                  add_risk_counts=True,
                  max_time=100,
                  title = "%s  (n=%s), %s, months"%("DASL",annot_dasl.shape[0],surv),
                  fig_file = "../img/Fig1C.pdf")
# Out:
# p-value=0.02
# HR=0.72(0.54-0.96)

# %%
surv = "PFS"
surv_event=surv+"_event"
surv_time=surv+"_time"

fitCPH_and_plotKM_treatments(annot_dasl,
                  surv_event=surv_event,
                  surv_time=surv_time,
                  covariates=covariates,
                  figsize=(5,4),
                  add_risk_counts=True,
                  max_time=100,
                  title = "%s  (n=%s), %s, months"%("DASL",annot_dasl.shape[0],surv),
                  fig_file = "../img/Fig1D.pdf")
# Out:
# p-value=0.01
# HR=0.72(0.56-0.91)
